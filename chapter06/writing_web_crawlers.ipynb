# %% [markdown]
# In this section, you’ll begin a project that will become a Six Degrees of Wikipedia solution finder: you’ll be able to take the Eric Idle page and find the fewest number of link clicks that will take you to the Kevin Bacon page.

# %%
from urllib.request import urlopen, urlparse
from bs4 import BeautifulSoup
import re 
import random

# %%
html = urlopen('http://en.wikipedia.org/wiki/Kevin_Bacon')
bs = BeautifulSoup(html, 'html.parser')
for link in bs.find_all('a'):
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# #bodyContent
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_upload_wizard
# /wiki/Main_Page
# /wiki/Special:Search
# /w/index.php?title=Special:CreateAccount&returnto=Kevin+Bacon
# /w/index.php?title=Special:UserLogin&returnto=Kevin+Bacon
# /w/index.php?title=Special:CreateAccount&returnto=Kevin+Bacon
# /w/index.php?title=Special:UserLogin&returnto=Kevin+Bacon
# /wiki/Help:Introduction
# /wiki/Special:MyContributions
# /wiki/Special:MyTalk
# #
# #Early_life_and_education
# #Acting_career
# #Early_work
# #1980s
# #1990s
# #2000s
# #2010s
# #Other_ventures
# #Six_Degrees_of_Kevin_Bacon
# #Personal_life
# #Accolades
# #Awards_and_nominations
# #Other_honors
# #See_also
# #References
# #External_links
# https://af.wikipedia.org/wiki/Kevin_Bacon
# https://ar.wikipedia.org/wiki/%D9%83%D9%8A%D9%81%D9%8A%D9%86_%D8%A8%D9%8A%D9%83%D9%86
# https://an.wikipedia.org/wiki/Kevin_Bacon
# https://ast.wikipedia.org/wiki/Kevin_Bacon
# https://azb.wikipedia.org/wiki/%DA%A9%D9%88%DB%8C%D9%86_%D8%A8%DB%8C%DA%A9%D9%86
# https://zh-min-nan.wikipedia.org/wiki/Kevin_Bacon
# https://be.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D1%96%D0%BD_%D0%91%D1%8D%D0%B9%D0%BA%D0%B0%D0%BD
# https://bi.wikipedia.org/wiki/Kevin_Bacon
# https://bg.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D0%B5%D0%B9%D0%BA%D1%8A%D0%BD
# https://bs.wikipedia.org/wiki/Kevin_Bacon
# https://ca.wikipedia.org/wiki/Kevin_Bacon
# https://cs.wikipedia.org/wiki/Kevin_Bacon
# https://da.wikipedia.org/wiki/Kevin_Bacon
# https://de.wikipedia.org/wiki/Kevin_Bacon
# https://el.wikipedia.org/wiki/%CE%9A%CE%AD%CE%B2%CE%B9%CE%BD_%CE%9C%CF%80%CE%AD%CE%B9%CE%BA%CE%BF%CE%BD
# https://eml.wikipedia.org/wiki/Kevin_Bacon
# https://es.wikipedia.org/wiki/Kevin_Bacon
# https://eo.wikipedia.org/wiki/Kevin_Bacon
# https://eu.wikipedia.org/wiki/Kevin_Bacon
# https://fa.wikipedia.org/wiki/%DA%A9%D9%88%DB%8C%D9%86_%D8%A8%DB%8C%DA%A9%D9%86
# https://fr.wikipedia.org/wiki/Kevin_Bacon
# https://ga.wikipedia.org/wiki/Kevin_Bacon
# https://gl.wikipedia.org/wiki/Kevin_Bacon
# https://ko.wikipedia.org/wiki/%EC%BC%80%EB%B9%88_%EB%B2%A0%EC%9D%B4%EC%BB%A8
# https://hy.wikipedia.org/wiki/%D5%94%D6%87%D5%AB%D5%B6_%D4%B2%D5%A5%D5%B5%D6%84%D5%B8%D5%B6
# https://hr.wikipedia.org/wiki/Kevin_Bacon
# https://io.wikipedia.org/wiki/Kevin_Bacon
# https://id.wikipedia.org/wiki/Kevin_Bacon
# https://it.wikipedia.org/wiki/Kevin_Bacon
# https://he.wikipedia.org/wiki/%D7%A7%D7%95%D7%95%D7%99%D7%9F_%D7%91%D7%99%D7%99%D7%A7%D7%95%D7%9F
# https://ka.wikipedia.org/wiki/%E1%83%99%E1%83%94%E1%83%95%E1%83%98%E1%83%9C_%E1%83%91%E1%83%94%E1%83%98%E1%83%99%E1%83%9D%E1%83%9C%E1%83%98
# https://kk.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D1%8D%D0%B9%D0%BA%D0%BE%D0%BD
# https://lv.wikipedia.org/wiki/Kevins_Beikons
# https://hu.wikipedia.org/wiki/Kevin_Bacon
# https://xmf.wikipedia.org/wiki/%E1%83%99%E1%83%94%E1%83%95%E1%83%98%E1%83%9C_%E1%83%91%E1%83%94%E1%83%98%E1%83%99%E1%83%9D%E1%83%9C%E1%83%98
# https://arz.wikipedia.org/wiki/%D9%83%D9%8A%D9%81%D9%8A%D9%86_%D8%A8%D9%8A%D9%83%D9%86
# https://ms.wikipedia.org/wiki/Kevin_Bacon
# https://mn.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D1%8D%D0%B9%D0%BA%D0%BE%D0%BD
# https://nl.wikipedia.org/wiki/Kevin_Bacon
# https://ja.wikipedia.org/wiki/%E3%82%B1%E3%83%B4%E3%82%A3%E3%83%B3%E3%83%BB%E3%83%99%E3%83%BC%E3%82%B3%E3%83%B3
# https://no.wikipedia.org/wiki/Kevin_Bacon
# https://oc.wikipedia.org/wiki/Kevin_Bacon
# https://uz.wikipedia.org/wiki/Kevin_Bacon
# https://pl.wikipedia.org/wiki/Kevin_Bacon
# https://pt.wikipedia.org/wiki/Kevin_Bacon
# https://ro.wikipedia.org/wiki/Kevin_Bacon
# https://ru.wikipedia.org/wiki/%D0%91%D0%B5%D0%B9%D0%BA%D0%BE%D0%BD,_%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD
# https://sco.wikipedia.org/wiki/Kevin_Bacon
# https://simple.wikipedia.org/wiki/Kevin_Bacon
# https://sk.wikipedia.org/wiki/Kevin_Bacon
# https://ckb.wikipedia.org/wiki/%DA%A9%DB%8E%DA%A4%D9%86_%D8%A8%DB%95%DB%8C%DA%A9%D9%86
# https://sr.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D0%B5%D1%98%D0%BA%D0%BE%D0%BD
# https://sh.wikipedia.org/wiki/Kevin_Bacon
# https://fi.wikipedia.org/wiki/Kevin_Bacon
# https://sv.wikipedia.org/wiki/Kevin_Bacon
# https://th.wikipedia.org/wiki/%E0%B9%80%E0%B8%84%E0%B8%A7%E0%B8%B4%E0%B8%99_%E0%B9%80%E0%B8%9A%E0%B8%84%E0%B8%AD%E0%B8%99
# https://tr.wikipedia.org/wiki/Kevin_Bacon
# https://uk.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D1%96%D0%BD_%D0%91%D0%B5%D0%B9%D0%BA%D0%BE%D0%BD
# https://vi.wikipedia.org/wiki/Kevin_Bacon
# https://wuu.wikipedia.org/wiki/%E5%87%AF%E6%96%87%C2%B7%E8%B4%9D%E8%82%AF
# https://zh-yue.wikipedia.org/wiki/%E5%A5%87%E9%9B%B2%E8%B2%9D%E6%A0%B9
# https://zh.wikipedia.org/wiki/%E5%87%AF%E6%96%87%C2%B7%E8%B4%9D%E8%82%AF
# https://www.wikidata.org/wiki/Special:EntityPage/Q3454165#sitelinks-wikipedia
# /wiki/Kevin_Bacon
# /wiki/Talk:Kevin_Bacon
# /wiki/Kevin_Bacon
# /w/index.php?title=Kevin_Bacon&action=edit
# /w/index.php?title=Kevin_Bacon&action=history
# /wiki/Kevin_Bacon
# /w/index.php?title=Kevin_Bacon&action=edit
# /w/index.php?title=Kevin_Bacon&action=history
# /wiki/Special:WhatLinksHere/Kevin_Bacon
# /wiki/Special:RecentChangesLinked/Kevin_Bacon
# /wiki/Wikipedia:File_Upload_Wizard
# /wiki/Special:SpecialPages
# /w/index.php?title=Kevin_Bacon&oldid=1231003484
# /w/index.php?title=Kevin_Bacon&action=info
# /w/index.php?title=Special:CiteThisPage&page=Kevin_Bacon&id=1231003484&wpFormIdentifier=titleform
# /w/index.php?title=Special:UrlShortener&url=https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FKevin_Bacon
# /w/index.php?title=Special:QrCode&url=https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FKevin_Bacon
# https://www.wikidata.org/wiki/Special:EntityPage/Q3454165
# /w/index.php?title=Special:DownloadAsPdf&page=Kevin_Bacon&action=show-download-screen
# /w/index.php?title=Kevin_Bacon&printable=yes
# https://commons.wikimedia.org/wiki/Kevin_Bacon
# /wiki/Wikipedia:Protection_policy#semi
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/File:Kevin_Bacon_in_2022.jpg
# /wiki/Peabody_Awards
# /wiki/Philadelphia
# /wiki/Kevin_Bacon_filmography
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# http://baconbros.com
# #cite_note-1
# #cite_note-actor-2
# /wiki/Leading_man
# /wiki/Character_actor
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/Primetime_Emmy_Award
# /wiki/National_Lampoon%27s_Animal_House
# /wiki/Footloose_(1984_film)
# /wiki/Diner_(1982_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Frost/Nixon_(film)
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Tremors_(1990_film)
# /wiki/The_River_Wild
# /wiki/The_Woodsman_(2004_film)
# /wiki/Crazy,_Stupid,_Love
# /wiki/X-Men:_First_Class
# /wiki/Patriots_Day_(film)
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Michael_Strobl
# /wiki/HBO
# /wiki/Taking_Chance
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# /wiki/Amazon_Prime_Video
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/Showtime_(TV_network)
# /wiki/City_on_a_Hill_(TV_series)
# #cite_note-3
# /wiki/The_Guardian
# /wiki/Academy_Award
# #cite_note-4
# /wiki/Hollywood_Walk_of_Fame
# #cite_note-5
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/EE_(telecommunications)
# #cite_note-6
# /wiki/Kyra_Sedgwick
# /wiki/Philadelphia
# #cite_note-actor-2
# #cite_note-actor-2
# /wiki/Edmund_Bacon_(architect)
# /wiki/Urban_planning
# /wiki/Design_of_Cities
# #cite_note-bacon-7
# /wiki/Julia_R._Masterman_School
# /wiki/Spring_Garden,_Philadelphia
# #cite_note-8
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Bucknell_University
# /wiki/Lewisburg,_Pennsylvania
# #cite_note-9
# /wiki/Glory_Van_Scott
# #cite_note-walk-10
# #cite_note-bacon-7
# /wiki/Kevin_Bacon_filmography
# /wiki/Circle_in_the_Square
# /wiki/Nancy_Mills
# /wiki/Cosmopolitan_(magazine)
# #cite_note-cosmo91-11
# /wiki/Fraternities_and_sororities
# /wiki/Animal_House
# #cite_note-bacon-7
# /wiki/Search_for_Tomorrow
# /wiki/Guiding_Light
# /wiki/Friday_the_13th_(1980_film)
# #cite_note-12
# /wiki/Getting_Out
# /wiki/Phoenix_Theater
# /wiki/Flux
# /wiki/Second_Stage_Theatre
# #cite_note-bio-13
# /wiki/Obie_Award
# /wiki/Forty_Deuce
# #cite_note-kevin-14
# /wiki/Slab_Boys
# /wiki/Sean_Penn
# /wiki/Val_Kilmer
# /wiki/Barry_Levinson
# /wiki/Diner_(1982_film)
# /wiki/Steve_Guttenberg
# /wiki/Daniel_Stern_(actor)
# /wiki/Mickey_Rourke
# /wiki/Tim_Daly
# /wiki/Ellen_Barkin
# #cite_note-15
# /wiki/Footloose_(1984_film)
# #cite_note-bio-13
# /wiki/James_Dean
# /wiki/Rebel_Without_a_Cause
# /wiki/Mickey_Rooney
# /wiki/Judy_Garland
# #cite_note-time84-16
# #cite_note-bacon-7
# #cite_note-17
# #cite_note-18
# /wiki/Typecasting_(acting)
# /wiki/John_Hughes_(filmmaker)
# /wiki/Planes,_Trains_and_Automobiles
# #cite_note-19
# /wiki/She%27s_Having_a_Baby
# #cite_note-bio-13
# /wiki/The_Big_Picture_(1989_film)
# #cite_note-20
# /wiki/Tremors_(1990_film)
# #cite_note-21
# /wiki/Joel_Schumacher
# /wiki/Flatliners
# #cite_note-bio-13
# /wiki/Elizabeth_Perkins
# /wiki/He_Said,_She_Said_(film)
# #cite_note-bio-13
# /wiki/The_New_York_Times
# #cite_note-nyt94-22
# /wiki/Oliver_Stone
# /wiki/JFK_(film)
# #cite_note-23
# /wiki/A_Few_Good_Men_(film)
# #cite_note-24
# /wiki/Michael_Greif
# #cite_note-bio-13
# /wiki/Golden_Globe_Award
# /wiki/The_River_Wild
# #cite_note-bio-13
# /wiki/Meryl_Streep
# /wiki/Murder_in_the_First_(film)
# #cite_note-bio-13
# /wiki/Blockbuster_(entertainment)
# /wiki/Apollo_13_(film)
# #cite_note-25
# /wiki/Sleepers_(film)
# #cite_note-26
# /wiki/Picture_Perfect_(1997_film)
# #cite_note-bio-13
# /wiki/Losing_Chase
# #cite_note-austin-27
# /wiki/Digging_to_China
# #cite_note-bio-13
# /wiki/Payola
# /wiki/Telling_Lies_in_America_(film)
# #cite_note-bio-13
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/David_Koepp
# #cite_note-28
# /wiki/File:Kevin_Bacon_Cannes_2004.jpg
# /wiki/Cannes_Film_Festival
# /wiki/Paul_Verhoeven
# /wiki/Hollow_Man
# #cite_note-29
# /wiki/Colin_Firth
# /wiki/Rachel_Blanchard
# /wiki/M%C3%A9nage_%C3%A0_trois
# /wiki/Where_the_Truth_Lies
# #cite_note-30
# /wiki/Atom_Egoyan
# /wiki/MPAA
# /wiki/MPAA_film_rating_system
# #cite_note-31
# /wiki/My_Dog_Skip_(film)
# #cite_note-32
# /wiki/Sean_Penn
# /wiki/Tim_Robbins
# /wiki/Clint_Eastwood
# /wiki/Mystic_River_(film)
# /wiki/The_Woodsman_(2004_film)
# #cite_note-33
# /wiki/Beauty_Shop
# /wiki/Queen_Latifah
# /wiki/HBO_Films
# /wiki/Taking_Chance
# /wiki/Michael_Strobl
# /wiki/Desert_Storm
# #cite_note-34
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/File:Black_Mass_PC_04_(21429102646).jpg
# /wiki/Toronto_Film_Festival
# /wiki/Matthew_Vaughn
# /wiki/X-Men:_First_Class
# /wiki/Sebastian_Shaw_(comics)
# #cite_note-35
# #cite_note-36
# /wiki/Crazy,_Stupid,_Love
# /wiki/Dustin_Lance_Black
# /wiki/8_(play)
# /wiki/Perry_v._Brown
# /wiki/Proposition_8
# /wiki/Charles_J._Cooper
# #cite_note-8_the_play-37
# /wiki/Wilshire_Ebell_Theatre
# /wiki/American_Foundation_for_Equal_Rights
# #cite_note-8_play_video-38
# #cite_note-39
# /wiki/The_Following
# #cite_note-40
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# #cite_note-41
# /wiki/Black_Mass_(film)
# /wiki/Johnny_Depp
# /wiki/Huffington_Post
# /wiki/Tremors_(1990_film)
# #cite_note-42
# /wiki/Tremors_5:_Bloodline
# /wiki/Patriots_Day_(film)
# /wiki/Boston_Marathon_bombing
# /wiki/The_Bacon_Brothers
# /wiki/Michael_Bacon_(musician)
# #cite_note-43
# /wiki/Instagram
# #cite_note-44
# /wiki/Old_97%27s
# /wiki/The_Guardians_of_the_Galaxy_Holiday_Special
# #cite_note-45
# /wiki/EE_(telecommunications)
# #cite_note-46
# #cite_note-47
# #cite_note-48
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Trivia
# /wiki/Big_screen
# /wiki/Six_degrees_of_separation
# /wiki/Internet_meme
# /wiki/SixDegrees.org
# /wiki/Social_networking_service
# #cite_note-49
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/IMDb
# #cite_note-50
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# #cite_note-51
# /wiki/File:Kevin_Bacon_2_SDCC_2014.jpg
# /wiki/Kyra_Sedgwick
# /wiki/PBS
# /wiki/Lanford_Wilson
# /wiki/Lemon_Sky
# #cite_note-cosmo91-11
# /wiki/Pyrates
# /wiki/Murder_in_the_First_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Loverboy_(2005_film)
# /w/index.php?title=Travis_Sedgwick&action=edit&redlink=1
# /wiki/Sosie_Bacon
# /wiki/Upper_West_Side
# /wiki/Manhattan
# #cite_note-52
# /wiki/Tracy_Pollan
# #cite_note-53
# /wiki/Separation_of_church_and_state_in_the_United_States
# #cite_note-54
# #cite_note-55
# /wiki/The_Times
# /wiki/Atheism
# #cite_note-56
# /wiki/Antireligion
# #cite_note-57
# /wiki/Will.i.am
# /wiki/It%27s_a_New_Day_(Will.i.am_song)
# /wiki/Barack_Obama
# /wiki/Ponzi_scheme
# /wiki/Bernie_Madoff
# #cite_note-financialpost-58
# #cite_note-59
# /wiki/Finding_Your_Roots
# /wiki/Henry_Louis_Gates
# #cite_note-60
# #cite_note-61
# #cite_note-62
# #cite_note-63
# /wiki/Apollo_13_(film)
# #cite_note-64
# /wiki/Mystic_River_(film)
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Blockbuster_Entertainment_Awards
# #cite_note-65
# /wiki/Hollow_Man
# /wiki/Boston_Society_of_Film_Critics
# /wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast
# #cite_note-66
# /wiki/Mystic_River_(film)
# /wiki/Bravo_Otto
# /wiki/Bravo_Otto
# /wiki/Footloose_(1984_film)
# /wiki/CableACE_Award
# /wiki/CableACE_Award
# /wiki/Losing_Chase
# /wiki/Chlotrudis_Awards
# /wiki/The_Woodsman_(2004_film)
# /wiki/Critics%27_Choice_Movie_Awards
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Murder_in_the_First_(film)
# /wiki/Ghent_International_Film_Festival
# /wiki/Ghent_International_Film_Festival
# /wiki/The_Woodsman_(2004_film)
# /wiki/Giffoni_Film_Festival
# /wiki/Giffoni_Film_Festival
# /wiki/Digging_to_China
# /wiki/Mystic_River_(film)
# /wiki/Golden_Globe_Award
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/The_River_Wild
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Independent_Spirit_Awards
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/The_Woodsman_(2004_film)
# /wiki/Mystic_River_(film)
# /wiki/MTV_Movie_%26_TV_Awards
# /wiki/MTV_Movie_Award_for_Best_Villain
# /wiki/Hollow_Man
# /wiki/Taking_Chance
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/Primetime_Emmy_Award
# /wiki/Primetime_Emmy_Award_for_Outstanding_Lead_Actor_in_a_Limited_Series_or_Movie
# /wiki/Taking_Chance
# /wiki/Satellite_Awards
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture
# /wiki/The_Woodsman_(2004_film)
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Saturn_Award
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Scream_Awards
# /wiki/Scream_Awards
# /wiki/X-Men:_First_Class
# /wiki/Screen_Actors_Guild_Award
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/Murder_in_the_First_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Apollo_13_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Mystic_River_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Frost/Nixon_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Taking_Chance
# /wiki/Teen_Choice_Awards
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Beauty_Shop
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/X-Men:_First_Class
# /wiki/TV_Guide_Award
# /wiki/TV_Guide_Award
# /wiki/The_Following
# /wiki/File:Kevin_Bacon%27s_Star_Walk_of_Fame.jpg
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Hollywood_Walk_of_Fame
# #cite_note-67
# /wiki/Denver_Film_Festival
# #cite_note-68
# /wiki/Phoenix_Film_Festival
# #cite_note-69
# /wiki/Santa_Barbara_International_Film_Festival
# #cite_note-70
# /wiki/Broadcast_Film_Critics_Association
# #cite_note-71
# /wiki/Seattle_International_Film_Festival
# #cite_note-72
# /wiki/List_of_actors_with_Hollywood_Walk_of_Fame_motion_picture_stars
# #cite_ref-1
# https://web.archive.org/web/20090113222205/http://www.newenglandancestors.org/research/services/articles_gbr78.asp
# http://www.newenglandancestors.org/research/services/articles_gbr78.asp
# #cite_ref-actor_2-0
# #cite_ref-actor_2-1
# #cite_ref-actor_2-2
# http://www.biography.com/people/kevin-bacon-9542173
# #cite_ref-3
# https://www.hollywoodreporter.com/tv/tv-news/showtime-cancels-city-on-a-hill-3-seasons-1235250089/
# /wiki/The_Hollywood_Reporter
# #cite_ref-4
# https://www.theguardian.com/film/filmblog/2009/feb/19/best-actors-never-nominated-for-oscars
# #cite_ref-5
# http://www.walkoffame.com/kevin-bacon
# #cite_ref-6
# https://www.marketingweek.com/ee-unveils-six-degrees-of-bacon-launch-ads/
# #cite_ref-bacon_7-0
# #cite_ref-bacon_7-1
# #cite_ref-bacon_7-2
# #cite_ref-bacon_7-3
# https://web.archive.org/web/20190403203113/https://www.biography.com/news/kevin-bacon-biography-facts
# http://www.biography.com/news/kevin-bacon-biography-facts
# #cite_ref-8
# https://philadelphia.cbslocal.com/top-lists/stars-from-philly-to-hollywood/
# #cite_ref-9
# https://movies.yahoo.com/person/kevin-bacon/biography.html
# #cite_ref-walk_10-0
# https://web.archive.org/web/20141016202657/http://www.thebiographychannel.co.uk/biographies/kevin-bacon.html
# http://www.thebiographychannel.co.uk/biographies/kevin-bacon.html
# #cite_ref-cosmo91_11-0
# #cite_ref-cosmo91_11-1
# #cite_ref-12
# http://www.nydailynews.com/entertainment/happy-halloween-superstars-start-horror-flick-gallery-1.98345
# #cite_ref-bio_13-0
# #cite_ref-bio_13-1
# #cite_ref-bio_13-2
# #cite_ref-bio_13-3
# #cite_ref-bio_13-4
# #cite_ref-bio_13-5
# #cite_ref-bio_13-6
# #cite_ref-bio_13-7
# #cite_ref-bio_13-8
# #cite_ref-bio_13-9
# #cite_ref-bio_13-10
# https://web.archive.org/web/20160530033240/http://www.pbs.org/weta/finding-your-roots/profiles/kevin-bacon%c2%a0/
# https://www.pbs.org/wnet/finding-your-roots/profiles/kevin-bacon%C2%A0/
# #cite_ref-kevin_14-0
# https://www.tvguide.com/celebrities/kevin-bacon/bio/160550
# #cite_ref-15
# https://web.archive.org/web/20141021030336/http://news.moviefone.com/2012/03/02/diner-30th-anniversary/
# http://news.moviefone.com/2012/03/02/diner-30th-anniversary/
# #cite_ref-time84_16-0
# https://web.archive.org/web/20080830035710/http://www.time.com/time/magazine/article/0,9171,950019,00.html
# http://www.time.com/time/magazine/article/0,9171,950019,00.html
# #cite_ref-17
# http://www.huffingtonpost.com/2014/08/25/kevin-bacon-footloose_n_5710413.html
# #cite_ref-18
# https://web.archive.org/web/20090109152125/http://www.thebiographychannel.co.uk/biography_story/522%3A492/1/Kevin_Bacon.htm
# http://www.thebiographychannel.co.uk/biography_story/522:492/1/Kevin_Bacon.htm
# #cite_ref-19
# https://www.mentalfloss.com/article/71594/14-moving-facts-about-planes-trains-and-automobiles
# #cite_ref-20
# https://www.nytimes.com/1994/09/25/movies/a-second-wind-is-blowing-for-kevin-bacon.html
# #cite_ref-21
# https://www.nytimes.com/movie/review?res=9C0CE2DE1631F93AA25752C0A966958260
# #cite_ref-nyt94_22-0
# https://query.nytimes.com/gst/fullpage.html?res=9C07E6D91F3BF936A1575AC0A962958260
# #cite_ref-23
# http://www.jfk-online.com/jfkbacon.html
# #cite_ref-24
# http://www.tcm.com/this-month/article/143158%7C0/A-Few-Good-Men.html
# #cite_ref-25
# http://collider.com/kevin-bacon-commercials-footloose/
# #cite_ref-26
# http://www.rogerebert.com/reviews/sleepers-1996
# #cite_ref-austin_27-0
# http://www.austinchronicle.com/calendar/film/1997-02-07/283342/
# /wiki/The_Austin_Chronicle
# #cite_ref-28
# http://www.criminalelement.com/blogs/2013/09/under-the-raderhorror-movies-you-may-have-missed-stir-of-echoes
# #cite_ref-29
# http://www.rogerebert.com/reviews/hollow-man-2000
# #cite_ref-30
# https://web.archive.org/web/20141017080013/http://movies.about.com/od/wherethetruthlies/a/truthkb101305.htm
# http://movies.about.com/od/wherethetruthlies/a/truthkb101305.htm
# #cite_ref-31
# https://archive.today/20120604150801/http://jam.canoe.ca/Movies/2005/09/14/1216527.html
# /wiki/Template:Cite_news
# /wiki/Category:CS1_maint:_unfit_URL
# #cite_ref-32
# https://archive.nytimes.com/www.nytimes.com/library/film/011200skip-film-review.html
# #cite_ref-33
# https://web.archive.org/web/20140802203026/http://www.latimes.com/entertainment/la-et-kevin-bacon-photo6-photo.html
# http://www.latimes.com/entertainment/la-et-kevin-bacon-photo6-photo.html
# #cite_ref-34
# http://www.nydailynews.com/entertainment/tv-movies/kevin-bacon-chance-body-fallen-marine-home-article-1.392226
# #cite_ref-35
# https://web.archive.org/web/20100722010545/http://heatvision.hollywoodreporter.com/2010/07/winters-bone-star-cast-as-mystique-in-xmen-first-class.html
# http://heatvision.hollywoodreporter.com/2010/07/winters-bone-star-cast-as-mystique-in-xmen-first-class.html
# #cite_ref-36
# https://web.archive.org/web/20100720060214/http://www.forcesofgeek.com/2010/07/kevin-bacon-playing-sebastian-shaw-in-x.html
# http://www.forcesofgeek.com/2010/07/kevin-bacon-playing-sebastian-shaw-in-x.html
# #cite_ref-8_the_play_37-0
# http://www.accesshollywood.com/jesse-tyler-ferguson/glee-stars-touched-by-brad-pitt-and-george-clooneys-support-of-8_article_61543
# /wiki/Access_Hollywood
# #cite_ref-8_play_video_38-0
# https://www.youtube.com/watch?v=qlUG8F9uVgM
# https://ghostarchive.org/varchive/youtube/20211211/qlUG8F9uVgM
# #cite_ref-39
# http://www.pinknews.co.uk/2012/03/01/youtube-to-broadcast-proposition-8-play-live/
# #cite_ref-40
# http://www.fox.com/the-following/
# #cite_ref-41
# https://news.yahoo.com/blogs/trending-now/kevin-bacon-gives-millennials-a-history-lesson-about-the--80s-162525915.html
# #cite_ref-42
# http://www.huffingtonpost.com.au/entry/kevin-bacon-tremors-tv-reboot_us_5655b651e4b072e9d1c13a11
# #cite_ref-43
# http://baconbros.com/
# #cite_ref-44
# https://www.instagram.com/p/ClUvj92p4Qn/?hl=en
# #cite_ref-45
# https://www.marvel.com/articles/tv-shows/guardians-of-the-galaxy-holiday-special-soundtrack
# #cite_ref-46
# http://www.campaignlive.co.uk/news/1294856/
# #cite_ref-47
# http://parade.condenast.com/269380/ashleighschmitz/kevin-bacon-reprises-his-most-iconic-film-roles-in-british-commercial/
# #cite_ref-48
# https://money.cnn.com/2015/03/13/media/kevin-bacon-eggs/index.html
# /wiki/CNN
# #cite_ref-49
# http://www.sixdegrees.org/
# #cite_ref-50
# http://www.webmonkey.com/2012/09/easter-egg-google-connects-the-dots-for-bacon-number-search/
# #cite_ref-51
# https://web.archive.org/web/20121112081753/http://www.telegraph.co.uk/science/science-news/4768389/And-the-winner-tonight-is.html
# https://www.telegraph.co.uk/science/science-news/4768389/And-the-winner-tonight-is.html
# #cite_ref-52
# http://www.nydailynews.com/entertainment/tv-movies/kevin-bacon-loyalty-nyc-philly-origins-peace-bustling-city-article-1.147197
# #cite_ref-53
# http://www.people.com/people/archive/article/0,,20093025,00.html
# #cite_ref-54
# https://web.archive.org/web/20141023014658/https://www.au.org/media/church-and-state/archives/2008/05/two-thumbs-up.html
# http://www.au.org/media/church-and-state/archives/2008/05/two-thumbs-up.html
# #cite_ref-55
# https://www.washingtonpost.com/wp-dyn/content/article/2008/03/25/AR2008032503852.html
# #cite_ref-56
# #cite_ref-57
# http://www.foxnews.com/story/0,2933,343589,00.html
# #cite_ref-financialpost_58-0
# https://web.archive.org/web/20140314085857/http://economiccrisis.us/2009/06/may-god-spare-mercy-victim-tells-madoff/
# http://economiccrisis.us/2009/06/may-god-spare-mercy-victim-tells-madoff/
# #cite_ref-59
# #cite_ref-60
# http://www.huffingtonpost.com/megan-smolenyak-smolenyak/6-degrees-of-separation-k_b_900707.html
# #cite_ref-61
# https://web.archive.org/web/20130405182304/http://www.drawtheline.org/watch-stuff/
# http://www.drawtheline.org/watch-stuff
# #cite_ref-62
# http://www.drawtheline.org/sign-now/
# #cite_ref-63
# https://web.archive.org/web/20190214002809/http://www.awardscircuit.com/2015/07/01/pixars-toy-story-wins-top-prize-for-1995-awards-circuit-community-awards/
# http://www.awardscircuit.com/2015/07/01/pixars-toy-story-wins-top-prize-for-1995-awards-circuit-community-awards/
# #cite_ref-64
# https://web.archive.org/web/20190520150327/http://www.awardscircuit.com/acca/the-acca-nominations-2003/
# http://www.awardscircuit.com/acca/the-acca-nominations-2003/
# #cite_ref-65
# https://idobi.com/news/nsync-takes-home-three-blockbuster-entertainment-awards/
# #cite_ref-66
# https://www.upi.com/Boston-critics-pick-Mystic-River/24961071506935/
# #cite_ref-67
# http://www.walkoffame.com/kevin-bacon
# #cite_ref-68
# https://www.imdb.com/event/ev0000209/2004/1/
# #cite_ref-69
# https://www.imdb.com/event/ev0000536/2005/1/
# #cite_ref-70
# https://www.imdb.com/event/ev0000589/2005/1/
# #cite_ref-71
# https://archive.today/20180123031007/http://www.criticschoice.com/movie-awards/critics%E2%80%99-choice-movie-awards-winners-archive/
# http://www.criticschoice.com/movie-awards/critics%E2%80%99-choice-movie-awards-winners-archive/
# #cite_ref-72
# https://www.imdb.com/event/ev0000600/2015/1/
# https://commons.wikimedia.org/wiki/Category:Kevin_Bacon
# https://www.imdb.com/name/nm0000102/
# /wiki/IMDb_(identifier)
# https://www.ibdb.com/broadway-cast-staff/90569
# /wiki/Internet_Broadway_Database
# https://www.wikidata.org/wiki/Q3454165#P1220
# http://www.iobdb.com/CreditableEntity/5597
# /wiki/Internet_Off-Broadway_Database
# https://www.allmovie.com/artist/p3164
# /wiki/AllMovie
# http://oracleofbacon.org
# /wiki/Template:Kevin_Bacon
# /wiki/Template_talk:Kevin_Bacon
# /wiki/Special:EditPage/Template:Kevin_Bacon
# /wiki/Kevin_Bacon_filmography
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/The_Bacon_Brothers
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/SixDegrees.org
# /wiki/Template:Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Template_talk:Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Special:EditPage/Template:Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Geoffrey_Rush
# /wiki/Jack_Nicholson
# /wiki/Ian_McKellen
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Daniel_Day-Lewis
# /wiki/Jack_Nicholson
# /wiki/Sean_Penn
# /wiki/Jamie_Foxx
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Daniel_Day-Lewis
# /wiki/Sean_Penn
# /wiki/Jeff_Bridges
# /wiki/Colin_Firth
# /wiki/George_Clooney
# /wiki/Daniel_Day-Lewis
# /wiki/Matthew_McConaughey
# /wiki/Michael_Keaton
# /wiki/Leonardo_DiCaprio
# /wiki/Casey_Affleck
# /wiki/Gary_Oldman
# /wiki/Christian_Bale
# /wiki/Joaquin_Phoenix
# /wiki/Chadwick_Boseman
# /wiki/Will_Smith
# /wiki/Brendan_Fraser
# /wiki/Paul_Giamatti
# /wiki/Template:Golden_Globe_Best_Actor_TV_Miniseries_Film
# /wiki/Template_talk:Golden_Globe_Best_Actor_TV_Miniseries_Film
# /wiki/Special:EditPage/Template:Golden_Globe_Best_Actor_TV_Miniseries_Film
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Mickey_Rooney
# /wiki/Anthony_Andrews
# /wiki/Richard_Chamberlain
# /wiki/Ted_Danson
# /wiki/Dustin_Hoffman
# /wiki/James_Woods
# /wiki/Randy_Quaid
# /wiki/Michael_Caine
# /wiki/Stacy_Keach
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Beau_Bridges
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Ving_Rhames
# /wiki/Stanley_Tucci
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/James_Franco
# /wiki/Albert_Finney
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Bill_Nighy
# /wiki/Jim_Broadbent
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Idris_Elba
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Billy_Bob_Thornton
# /wiki/Oscar_Isaac
# /wiki/Tom_Hiddleston
# /wiki/Ewan_McGregor
# /wiki/Darren_Criss
# /wiki/Russell_Crowe
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Evan_Peters
# /wiki/Steven_Yeun
# /wiki/Template:Saturn_Award_for_Best_Actor_on_Television
# /wiki/Template_talk:Saturn_Award_for_Best_Actor_on_Television
# /wiki/Special:EditPage/Template:Saturn_Award_for_Best_Actor_on_Television
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Kyle_Chandler
# /wiki/Steven_Weber_(actor)
# /wiki/Richard_Dean_Anderson
# /wiki/David_Boreanaz
# /wiki/Robert_Patrick
# /wiki/Ben_Browder
# /wiki/David_Boreanaz
# /wiki/David_Boreanaz
# /wiki/Ben_Browder
# /wiki/Matthew_Fox
# /wiki/Michael_C._Hall
# /wiki/Matthew_Fox
# /wiki/Edward_James_Olmos
# /wiki/Josh_Holloway
# /wiki/Stephen_Moyer
# /wiki/Bryan_Cranston
# /wiki/Bryan_Cranston
# /wiki/Mads_Mikkelsen
# /wiki/Hugh_Dancy
# /wiki/Andrew_Lincoln
# /wiki/Bruce_Campbell
# /wiki/Andrew_Lincoln
# /wiki/Kyle_MacLachlan
# /wiki/Patrick_Stewart
# /wiki/Saturn_Award_for_Best_Actor_in_a_Network_or_Cable_Television_Series
# /wiki/Sam_Heughan
# /wiki/Bob_Odenkirk
# /wiki/Saturn_Award_for_Best_Actor_in_a_Streaming_Television_Series
# /wiki/Henry_Thomas
# /wiki/Oscar_Isaac
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Patrick_Stewart
# /wiki/Template:ScreenActorsGuildAward_MaleTVMiniseriesMovie
# /wiki/Template_talk:ScreenActorsGuildAward_MaleTVMiniseriesMovie
# /wiki/Special:EditPage/Template:ScreenActorsGuildAward_MaleTVMiniseriesMovie
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Gary_Sinise
# /wiki/Christopher_Reeve
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/Ben_Kingsley
# /wiki/William_H._Macy
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Paul_Newman
# /wiki/Jeremy_Irons
# /wiki/Kevin_Kline
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Paul_Giamatti
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Mark_Ruffalo
# /wiki/Idris_Elba
# /wiki/Bryan_Cranston
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Darren_Criss
# /wiki/Sam_Rockwell
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Sam_Elliott
# /wiki/Steven_Yeun
# /wiki/Help:Authority_control
# https://www.wikidata.org/wiki/Q3454165#identifiers
# http://id.worldcat.org/fast/242183/
# https://isni.org/isni/0000000121291300
# https://viaf.org/viaf/39570812
# https://id.oclc.org/worldcat/entity/E39PBJyWTmRrCjK87VWCKb9v73
# https://authority.bibsys.no/authority/rest/authorities/html/98015093
# http://catalogo.bne.es/uhtbin/authoritybrowse.cgi?action=display&authority_id=XX1298810
# https://catalogue.bnf.fr/ark:/12148/cb139817766
# https://data.bnf.fr/ark:/12148/cb139817766
# https://d-nb.info/gnd/124109659
# http://olduli.nli.org.il/F/?func=find-b&local_base=NLX10&find_code=UID&request=987007454685905171
# https://id.loc.gov/authorities/n88034930
# https://kopkatalogs.lv/F?func=direct&local_base=lnc10&doc_number=000249798&P_CON_LNG=ENG
# https://aleph.nkp.cz/F/?func=find-c&local_base=aut&ccl_term=ica=xx0025279&CON_LNG=ENG
# https://nla.gov.au/anbd.aut-an36021861
# https://lod.nl.go.kr/resource/KAC2020K8226
# http://data.bibliotheken.nl/id/thes/p147880998
# https://dbn.bn.org.pl/descriptor-details/9810630778405606
# https://musicbrainz.org/artist/cc0dbdfc-9b2c-4e31-8448-808412388406
# https://trove.nla.gov.au/people/1189569
# https://snaccooperative.org/ark:/99166/w6w67gw2
# https://www.idref.fr/067287832
# https://en.wikipedia.org/w/index.php?title=Kevin_Bacon&oldid=1231003484
# /wiki/Help:Category
# /wiki/Category:1958_births
# /wiki/Category:20th-century_American_male_actors
# /wiki/Category:21st-century_American_male_actors
# /wiki/Category:American_atheists
# /wiki/Category:American_male_film_actors
# /wiki/Category:American_male_soap_opera_actors
# /wiki/Category:American_male_television_actors
# /wiki/Category:American_male_voice_actors
# /wiki/Category:The_Bacon_Brothers_members
# /wiki/Category:Best_Miniseries_or_Television_Movie_Actor_Golden_Globe_winners
# /wiki/Category:Circle_in_the_Square_Theatre_School_alumni
# /wiki/Category:Living_people
# /wiki/Category:Male_actors_from_Philadelphia
# /wiki/Category:Obie_Award_recipients
# /wiki/Category:Outstanding_Performance_by_a_Cast_in_a_Motion_Picture_Screen_Actors_Guild_Award_winners
# /wiki/Category:Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie_Screen_Actors_Guild_Award_winners
# /wiki/Category:Sedgwick_family
# /wiki/Category:Male_actors_from_Manhattan
# /wiki/Category:People_from_the_Upper_West_Side
# /wiki/Category:CS1_maint:_unfit_URL
# /wiki/Category:Use_American_English_from_April_2023
# /wiki/Category:All_Wikipedia_articles_written_in_American_English
# /wiki/Category:Articles_with_short_description
# /wiki/Category:Short_description_matches_Wikidata
# /wiki/Category:Wikipedia_indefinitely_semi-protected_biographies_of_living_people
# /wiki/Category:Use_mdy_dates_from_April_2023
# /wiki/Category:Articles_with_hCards
# /wiki/Category:Commons_category_link_from_Wikidata
# /wiki/Category:IBDB_name_template_using_Wikidata
# /wiki/Category:Internet_Off-Broadway_Database_person_ID_same_as_Wikidata
# /wiki/Category:Articles_with_FAST_identifiers
# /wiki/Category:Articles_with_ISNI_identifiers
# /wiki/Category:Articles_with_VIAF_identifiers
# /wiki/Category:Articles_with_WorldCat_Entities_identifiers
# /wiki/Category:Articles_with_BIBSYS_identifiers
# /wiki/Category:Articles_with_BNE_identifiers
# /wiki/Category:Articles_with_BNF_identifiers
# /wiki/Category:Articles_with_BNFdata_identifiers
# /wiki/Category:Articles_with_GND_identifiers
# /wiki/Category:Articles_with_J9U_identifiers
# /wiki/Category:Articles_with_LCCN_identifiers
# /wiki/Category:Articles_with_LNB_identifiers
# /wiki/Category:Articles_with_NKC_identifiers
# /wiki/Category:Articles_with_NLA_identifiers
# /wiki/Category:Articles_with_NLK_identifiers
# /wiki/Category:Articles_with_NTA_identifiers
# /wiki/Category:Articles_with_PLWABN_identifiers
# /wiki/Category:Articles_with_MusicBrainz_identifiers
# /wiki/Category:Articles_with_Trove_identifiers
# /wiki/Category:Articles_with_SNAC-ID_identifiers
# /wiki/Category:Articles_with_SUDOC_identifiers
# //en.wikipedia.org/wiki/Wikipedia:Text_of_the_Creative_Commons_Attribution-ShareAlike_4.0_International_License
# //en.wikipedia.org/wiki/Wikipedia:Text_of_the_Creative_Commons_Attribution-ShareAlike_4.0_International_License
# //foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Terms_of_Use
# //foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy
# //www.wikimediafoundation.org/
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy
# /wiki/Wikipedia:About
# /wiki/Wikipedia:General_disclaimer
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Universal_Code_of_Conduct
# https://developer.wikimedia.org
# https://stats.wikimedia.org/#/en.wikipedia.org
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Cookie_statement
# //en.m.wikipedia.org/w/index.php?title=Kevin_Bacon&mobileaction=toggle_view_mobile
# https://wikimediafoundation.org/
# https://www.mediawiki.org

# %% [markdown]
# Si examinas los enlaces que apuntan a páginas de artículos (a diferencia de otras páginas internas), verás que todos tienen tres cosas en común:
#
# * Residen dentro del div con el id configurado en bodyContent.
#
# * Las URL no contienen dos puntos.
#
# * Las URL comienzan con /wiki/.

# %%
for link in bs.find('div', {'id':'bodyContent'}).find_all(
    'a', href=re.compile('^(/wiki/)((?!:).)*$')): # ((?!:).) -> Esta combinación dice "cualquier carácter que no sea :".
    print(link.attrs['href'])
                                                # El asterisco * significa "cero o más" de la combinación anterior (((?!:).)). Es decir, busca cualquier secuencia de caracteres que no contenga :.
# Out:
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/Peabody_Awards
# /wiki/Philadelphia
# /wiki/Kevin_Bacon_filmography
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/Leading_man
# /wiki/Character_actor
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/Primetime_Emmy_Award
# /wiki/National_Lampoon%27s_Animal_House
# /wiki/Footloose_(1984_film)
# /wiki/Diner_(1982_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Frost/Nixon_(film)
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Tremors_(1990_film)
# /wiki/The_River_Wild
# /wiki/The_Woodsman_(2004_film)
# /wiki/Crazy,_Stupid,_Love
# /wiki/Patriots_Day_(film)
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Michael_Strobl
# /wiki/HBO
# /wiki/Taking_Chance
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# /wiki/Amazon_Prime_Video
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/Showtime_(TV_network)
# /wiki/City_on_a_Hill_(TV_series)
# /wiki/The_Guardian
# /wiki/Academy_Award
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/EE_(telecommunications)
# /wiki/Kyra_Sedgwick
# /wiki/Philadelphia
# /wiki/Edmund_Bacon_(architect)
# /wiki/Urban_planning
# /wiki/Design_of_Cities
# /wiki/Julia_R._Masterman_School
# /wiki/Spring_Garden,_Philadelphia
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Bucknell_University
# /wiki/Lewisburg,_Pennsylvania
# /wiki/Glory_Van_Scott
# /wiki/Kevin_Bacon_filmography
# /wiki/Circle_in_the_Square
# /wiki/Nancy_Mills
# /wiki/Cosmopolitan_(magazine)
# /wiki/Fraternities_and_sororities
# /wiki/Animal_House
# /wiki/Search_for_Tomorrow
# /wiki/Guiding_Light
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Getting_Out
# /wiki/Phoenix_Theater
# /wiki/Flux
# /wiki/Second_Stage_Theatre
# /wiki/Obie_Award
# /wiki/Forty_Deuce
# /wiki/Slab_Boys
# /wiki/Sean_Penn
# /wiki/Val_Kilmer
# /wiki/Barry_Levinson
# /wiki/Diner_(1982_film)
# /wiki/Steve_Guttenberg
# /wiki/Daniel_Stern_(actor)
# /wiki/Mickey_Rourke
# /wiki/Tim_Daly
# /wiki/Ellen_Barkin
# /wiki/Footloose_(1984_film)
# /wiki/James_Dean
# /wiki/Rebel_Without_a_Cause
# /wiki/Mickey_Rooney
# /wiki/Judy_Garland
# /wiki/Typecasting_(acting)
# /wiki/John_Hughes_(filmmaker)
# /wiki/Planes,_Trains_and_Automobiles
# /wiki/She%27s_Having_a_Baby
# /wiki/The_Big_Picture_(1989_film)
# /wiki/Tremors_(1990_film)
# /wiki/Joel_Schumacher
# /wiki/Flatliners
# /wiki/Elizabeth_Perkins
# /wiki/He_Said,_She_Said_(film)
# /wiki/The_New_York_Times
# /wiki/Oliver_Stone
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men_(film)
# /wiki/Michael_Greif
# /wiki/Golden_Globe_Award
# /wiki/The_River_Wild
# /wiki/Meryl_Streep
# /wiki/Murder_in_the_First_(film)
# /wiki/Blockbuster_(entertainment)
# /wiki/Apollo_13_(film)
# /wiki/Sleepers_(film)
# /wiki/Picture_Perfect_(1997_film)
# /wiki/Losing_Chase
# /wiki/Digging_to_China
# /wiki/Payola
# /wiki/Telling_Lies_in_America_(film)
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/David_Koepp
# /wiki/Cannes_Film_Festival
# /wiki/Paul_Verhoeven
# /wiki/Hollow_Man
# /wiki/Colin_Firth
# /wiki/Rachel_Blanchard
# /wiki/M%C3%A9nage_%C3%A0_trois
# /wiki/Where_the_Truth_Lies
# /wiki/Atom_Egoyan
# /wiki/MPAA
# /wiki/MPAA_film_rating_system
# /wiki/My_Dog_Skip_(film)
# /wiki/Sean_Penn
# /wiki/Tim_Robbins
# /wiki/Clint_Eastwood
# /wiki/Mystic_River_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Beauty_Shop
# /wiki/Queen_Latifah
# /wiki/HBO_Films
# /wiki/Taking_Chance
# /wiki/Michael_Strobl
# /wiki/Desert_Storm
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Toronto_Film_Festival
# /wiki/Matthew_Vaughn
# /wiki/Sebastian_Shaw_(comics)
# /wiki/Crazy,_Stupid,_Love
# /wiki/Dustin_Lance_Black
# /wiki/8_(play)
# /wiki/Perry_v._Brown
# /wiki/Proposition_8
# /wiki/Charles_J._Cooper
# /wiki/Wilshire_Ebell_Theatre
# /wiki/American_Foundation_for_Equal_Rights
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Black_Mass_(film)
# /wiki/Johnny_Depp
# /wiki/Huffington_Post
# /wiki/Tremors_(1990_film)
# /wiki/Patriots_Day_(film)
# /wiki/Boston_Marathon_bombing
# /wiki/The_Bacon_Brothers
# /wiki/Michael_Bacon_(musician)
# /wiki/Instagram
# /wiki/Old_97%27s
# /wiki/The_Guardians_of_the_Galaxy_Holiday_Special
# /wiki/EE_(telecommunications)
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Trivia
# /wiki/Big_screen
# /wiki/Six_degrees_of_separation
# /wiki/Internet_meme
# /wiki/SixDegrees.org
# /wiki/Social_networking_service
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/IMDb
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/Kyra_Sedgwick
# /wiki/PBS
# /wiki/Lanford_Wilson
# /wiki/Lemon_Sky
# /wiki/Pyrates
# /wiki/Murder_in_the_First_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Loverboy_(2005_film)
# /wiki/Sosie_Bacon
# /wiki/Upper_West_Side
# /wiki/Manhattan
# /wiki/Tracy_Pollan
# /wiki/Separation_of_church_and_state_in_the_United_States
# /wiki/The_Times
# /wiki/Atheism
# /wiki/Antireligion
# /wiki/Will.i.am
# /wiki/It%27s_a_New_Day_(Will.i.am_song)
# /wiki/Barack_Obama
# /wiki/Ponzi_scheme
# /wiki/Bernie_Madoff
# /wiki/Finding_Your_Roots
# /wiki/Henry_Louis_Gates
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Hollow_Man
# /wiki/Boston_Society_of_Film_Critics
# /wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast
# /wiki/Mystic_River_(film)
# /wiki/Bravo_Otto
# /wiki/Bravo_Otto
# /wiki/Footloose_(1984_film)
# /wiki/CableACE_Award
# /wiki/CableACE_Award
# /wiki/Losing_Chase
# /wiki/Chlotrudis_Awards
# /wiki/The_Woodsman_(2004_film)
# /wiki/Critics%27_Choice_Movie_Awards
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Murder_in_the_First_(film)
# /wiki/Ghent_International_Film_Festival
# /wiki/Ghent_International_Film_Festival
# /wiki/The_Woodsman_(2004_film)
# /wiki/Giffoni_Film_Festival
# /wiki/Giffoni_Film_Festival
# /wiki/Digging_to_China
# /wiki/Mystic_River_(film)
# /wiki/Golden_Globe_Award
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/The_River_Wild
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Independent_Spirit_Awards
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/The_Woodsman_(2004_film)
# /wiki/Mystic_River_(film)
# /wiki/MTV_Movie_%26_TV_Awards
# /wiki/MTV_Movie_Award_for_Best_Villain
# /wiki/Hollow_Man
# /wiki/Taking_Chance
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/Primetime_Emmy_Award
# /wiki/Primetime_Emmy_Award_for_Outstanding_Lead_Actor_in_a_Limited_Series_or_Movie
# /wiki/Taking_Chance
# /wiki/Satellite_Awards
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture
# /wiki/The_Woodsman_(2004_film)
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Saturn_Award
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Scream_Awards
# /wiki/Scream_Awards
# /wiki/Screen_Actors_Guild_Award
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/Murder_in_the_First_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Apollo_13_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Mystic_River_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Frost/Nixon_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Taking_Chance
# /wiki/Teen_Choice_Awards
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Beauty_Shop
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/TV_Guide_Award
# /wiki/TV_Guide_Award
# /wiki/The_Following
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Denver_Film_Festival
# /wiki/Phoenix_Film_Festival
# /wiki/Santa_Barbara_International_Film_Festival
# /wiki/Broadcast_Film_Critics_Association
# /wiki/Seattle_International_Film_Festival
# /wiki/List_of_actors_with_Hollywood_Walk_of_Fame_motion_picture_stars
# /wiki/The_Hollywood_Reporter
# /wiki/The_Austin_Chronicle
# /wiki/Access_Hollywood
# /wiki/CNN
# /wiki/IMDb_(identifier)
# /wiki/Internet_Broadway_Database
# /wiki/Internet_Off-Broadway_Database
# /wiki/AllMovie
# /wiki/Kevin_Bacon_filmography
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/The_Bacon_Brothers
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/SixDegrees.org
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Geoffrey_Rush
# /wiki/Jack_Nicholson
# /wiki/Ian_McKellen
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Daniel_Day-Lewis
# /wiki/Jack_Nicholson
# /wiki/Sean_Penn
# /wiki/Jamie_Foxx
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Daniel_Day-Lewis
# /wiki/Sean_Penn
# /wiki/Jeff_Bridges
# /wiki/Colin_Firth
# /wiki/George_Clooney
# /wiki/Daniel_Day-Lewis
# /wiki/Matthew_McConaughey
# /wiki/Michael_Keaton
# /wiki/Leonardo_DiCaprio
# /wiki/Casey_Affleck
# /wiki/Gary_Oldman
# /wiki/Christian_Bale
# /wiki/Joaquin_Phoenix
# /wiki/Chadwick_Boseman
# /wiki/Will_Smith
# /wiki/Brendan_Fraser
# /wiki/Paul_Giamatti
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Mickey_Rooney
# /wiki/Anthony_Andrews
# /wiki/Richard_Chamberlain
# /wiki/Ted_Danson
# /wiki/Dustin_Hoffman
# /wiki/James_Woods
# /wiki/Randy_Quaid
# /wiki/Michael_Caine
# /wiki/Stacy_Keach
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Beau_Bridges
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Ving_Rhames
# /wiki/Stanley_Tucci
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/James_Franco
# /wiki/Albert_Finney
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Bill_Nighy
# /wiki/Jim_Broadbent
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Idris_Elba
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Billy_Bob_Thornton
# /wiki/Oscar_Isaac
# /wiki/Tom_Hiddleston
# /wiki/Ewan_McGregor
# /wiki/Darren_Criss
# /wiki/Russell_Crowe
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Evan_Peters
# /wiki/Steven_Yeun
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Kyle_Chandler
# /wiki/Steven_Weber_(actor)
# /wiki/Richard_Dean_Anderson
# /wiki/David_Boreanaz
# /wiki/Robert_Patrick
# /wiki/Ben_Browder
# /wiki/David_Boreanaz
# /wiki/David_Boreanaz
# /wiki/Ben_Browder
# /wiki/Matthew_Fox
# /wiki/Michael_C._Hall
# /wiki/Matthew_Fox
# /wiki/Edward_James_Olmos
# /wiki/Josh_Holloway
# /wiki/Stephen_Moyer
# /wiki/Bryan_Cranston
# /wiki/Bryan_Cranston
# /wiki/Mads_Mikkelsen
# /wiki/Hugh_Dancy
# /wiki/Andrew_Lincoln
# /wiki/Bruce_Campbell
# /wiki/Andrew_Lincoln
# /wiki/Kyle_MacLachlan
# /wiki/Patrick_Stewart
# /wiki/Saturn_Award_for_Best_Actor_in_a_Network_or_Cable_Television_Series
# /wiki/Sam_Heughan
# /wiki/Bob_Odenkirk
# /wiki/Saturn_Award_for_Best_Actor_in_a_Streaming_Television_Series
# /wiki/Henry_Thomas
# /wiki/Oscar_Isaac
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Patrick_Stewart
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Gary_Sinise
# /wiki/Christopher_Reeve
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/Ben_Kingsley
# /wiki/William_H._Macy
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Paul_Newman
# /wiki/Jeremy_Irons
# /wiki/Kevin_Kline
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Paul_Giamatti
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Mark_Ruffalo
# /wiki/Idris_Elba
# /wiki/Bryan_Cranston
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Darren_Criss
# /wiki/Sam_Rockwell
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Sam_Elliott
# /wiki/Steven_Yeun

# %% [markdown]
# A more complex crawler

# %%
import datetime
import random

random.seed(datetime.datetime.now().microsecond)
def getLinks(articleUrl):
    html = urlopen('http://en.wikipedia.org{}'.format(articleUrl))
    bs = BeautifulSoup(html, 'html.parser')
    return bs.find('div', {'id': 'bodyContent'}).find_all('a', href=re.compile('^(/wiki/)((?!:).)*$'))

links = getLinks('/wiki/Kevin_Bacon')
while len(links) > 0:
    newArticle = links[random.randint(0, len(links)-1)].attrs['href']
    print(newArticle)
    links = getLinks(newArticle)
# Out:
# /wiki/HBO_Films
# /wiki/Chris_Albrecht
# /wiki/HBO_Original_Programming
# /wiki/Sky_One
# /wiki/Sky_Mix
# /wiki/Road_Wars_(TV_series)
# /wiki/Sick_of_It_(TV_series)
# /wiki/Ross_Kemp_in_Search_of_Pirates
# /wiki/The_Race_(TV_series)
# /wiki/Project_Catwalk
# /wiki/Louie_Spence%27s_Showbusiness
# /wiki/Wolfe_(TV_series)
# /wiki/After_Hours_(2015_British_TV_series)
# /wiki/Police_Stop!
# /wiki/The_Race_(TV_series)
# /wiki/Mad_Dogs_(British_TV_series)
# /wiki/British_Academy_Television_Awards_2011
# /wiki/2021_British_Academy_Television_Awards
# /wiki/The_Ranganation
# /wiki/Broadcast_Awards
# /wiki/Debbie_tucker_green
# /wiki/Channel_4
# /wiki/The_Comic_Strip
# /wiki/Arnold_Brown_(comedian)
# /wiki/Sarah_Millican
# /wiki/The_Bubble_(UK_TV_series)
# /wiki/Marcus_Brigstocke
# /wiki/Television
# /wiki/Philadelphia
# /wiki/Atlantic_City,_New_Jersey
# /wiki/Wilmington,_Delaware
# /wiki/1860_United_States_census
# /wiki/Maine
# /wiki/Foreign_policy_of_the_United_States
# /wiki/Iran%E2%80%93Iraq_War
# /wiki/2004_Qamishli_riots
# /wiki/Popular_Front_for_Change_and_Liberation
# /wiki/Al_Akhbar_(Lebanon)
# /wiki/Al_Bayrak
# /wiki/Al-Mustaqbal_(newspaper)
# /wiki/Ike_(daily)
# /wiki/Zartonk_(Lebanese_daily)
# /wiki/Lebanon
# /wiki/Phoenice_(Roman_province)
# /wiki/List_of_Roman_governors_of_Moesia
# /wiki/Moesia
# /wiki/Valens
# /wiki/Julian_(emperor)
# /wiki/Florentius_(prefect)
# /wiki/Anatolius_(praetorian_prefect)
# /wiki/Florentinus
# /wiki/Decurion_(administrative)
# /wiki/Roman_citizen
# /wiki/Triumvir_monetalis
# /wiki/Temple_of_Juno_Moneta
# /wiki/Palazzo_Zuccari,_Rome
# /wiki/Tomb_of_the_Scipios
# /wiki/Galleria_Spada
# /wiki/Giacinto_Campana
# /wiki/Francesco_Albani
# /wiki/Dresden
# /wiki/Hans_von_B%C3%BClow
# /wiki/Der_Ring_des_Nibelungen
# /wiki/George_Bernard_Shaw
# /wiki/James_Agate
# /wiki/Pendleton,_Greater_Manchester
# /wiki/Member_of_parliament#United_Kingdom
# /wiki/Teachta_D%C3%A1la
# /wiki/Republic_of_Ireland
# /wiki/Association_football_in_Northern_Ireland
# /wiki/Northern_Ireland_football_league_system
# /wiki/Newington_F.C.
# /wiki/Inver_Park
# /wiki/Northern_Ireland
# /wiki/Rail_transport_in_the_United_Kingdom
# /wiki/Pembroke_Dock
# /wiki/Manorbier_railway_station
# /wiki/Saundersfoot_railway_station
# /wiki/National_Cycle_Route_4
# /wiki/Swansea_University
# /wiki/Swansea_City
# /wiki/Scotland
# /wiki/1716_in_Scotland
# /wiki/1845_in_Scotland
# /wiki/Timeline_of_Scottish_history
# /wiki/1731_in_Scotland
# /wiki/1862_in_Scotland
# /wiki/Portpatrick
# /wiki/Clachanmore
# /wiki/Scottish_Gaelic_language
# /wiki/Renaissance_in_Scotland
# /wiki/Italian_Renaissance
# /wiki/Regiomontanus
# /wiki/Tangent_table
# /wiki/Rational_function
# /wiki/Domain_of_a_function
# /wiki/Logical_connective
# /wiki/Validity_(logic)
# /wiki/Logical_consequence
# /wiki/Index_of_logic_articles
# /wiki/Logical_conjunction
# /wiki/Sierpinski_triangle
# /wiki/Ian_Stewart_(mathematician)
# /wiki/University_of_Houston
# /wiki/Washington_Monthly#College_rankings
# /wiki/Nicholas_Thompson_(editor)
# /wiki/Phillips_Academy
# /wiki/Westminster_School_(Connecticut)
# /wiki/Deerfield_Academy
# /wiki/Eagle_Hill_School
# /wiki/Princeton_Day_School
# /wiki/The_Bronx
# /wiki/The_Hub,_Bronx
# /wiki/Bx2_(New_York_City_bus)
# /wiki/Bx14_(New_York_City_bus)
# /wiki/Co-op_City,_Bronx
# /wiki/New_York_Daily_News
# /wiki/Park_Row_(Manhattan)
# /wiki/Albany_Street_(Manhattan)
# /wiki/Excelsior_Power_Company_Building
# /wiki/Zuccotti_Park
# /wiki/Riverside_Park_(Manhattan)
# /wiki/PDF
# /wiki/RFC_(identifier)
# /wiki/Jon_Postel
# /wiki/Curlie
# /wiki/Web_directory
# /wiki/Lists_of_websites
# /wiki/List_of_social_networking_services
# /wiki/Threads_(social_network)
# /wiki/List_of_Facebook_features
# /wiki/Messenger_Kids
# /wiki/Parental_controls
# /wiki/Digital_television
# /wiki/RAI
# /wiki/ZDF
# /wiki/ITV_plc
# /wiki/Sunday_Sport
# /wiki/Television_in_Wales
# /wiki/Broadcasting_House,_Cardiff
# /wiki/MTV_(British_and_Irish_TV_channel)
# /wiki/BBC_Pacific_Quay
# /wiki/Pearson_plc
# /wiki/Screen_International
# /wiki/Ronke_Adekoluejo
# /wiki/Doctor_Who
# /wiki/Doctor_Who_%E2%80%93_Battles_in_Time
# /wiki/List_of_Doctor_Who_home_video_releases
# /wiki/The_Invasion_of_Time
# /wiki/The_War_Doctor_(audio_drama_series)
# /wiki/John_Dorney
# /wiki/My_First_Planet
# /wiki/John_Dorney
# /wiki/Jago_and_Litefoot
# /wiki/Vengeance_on_Varos
# /wiki/Doctor_Who_(season_22)
# /wiki/Doctor_Who_season_14
# /wiki/Leela_(Doctor_Who)
# /wiki/Jenny_(Doctor_Who)
# /wiki/Digital_Spy
# /wiki/KQCA
# /wiki/Magnificent_Movies_Network
# /wiki/Milwaukee_Journal_Sentinel
# /wiki/The_Daily_Ledger
# /wiki/Lansing_State_Journal
# /wiki/Lansing,_Michigan
# /wiki/Jef_Mallett
# /wiki/Ironman_World_Championship
# /wiki/Daniela_Ryf
# /wiki/Paula_Newby-Fraser
# /wiki/Ironman_World_Championship
# /wiki/Motorsport
# /wiki/Road_racing
# /wiki/Firestone_Grand_Prix_of_St._Petersburg
# /wiki/Colombia
# /wiki/Judiciary_of_Colombia
# /wiki/Judiciary_of_Peru
# /wiki/Mass_media_in_Peru
# /wiki/Peru
# /wiki/List_of_lakes_of_Peru
# /wiki/Huaroncocha
# /wiki/Huayllay_District
# /wiki/Mayor
# /wiki/Norway
# /wiki/Klemens_Wenzel,_Prince_von_Metternich
# /wiki/Italian_school_of_elitism
# /wiki/Ordered_liberty
# /wiki/Ludwig_von_Mises
# /wiki/Georgism
# /wiki/Elbert_Hubbard
# /wiki/Mack_Bolan
# /wiki/Innovation_Publishing
# /wiki/Sumerian_Comics
# /wiki/Michael_Douglas
# /wiki/Benedict_Cumberbatch
# /wiki/Daniel_Day-Lewis
# /wiki/Robert_De_Niro
# /wiki/Mean_Streets
# /wiki/Boxcar_Bertha
# /wiki/A_Personal_Journey_with_Martin_Scorsese_Through_American_Movies
# /wiki/My_Dream_Is_Yours
# /wiki/Doris_Day
# /wiki/Love_the_Way_You_Lie
# /wiki/Won%27t_Back_Down_(Eminem_song)
# /wiki/Normal_(Eminem_song)
# /wiki/List_of_music_recording_certifications
# /wiki/Poland
# /wiki/Planned_economy
# /wiki/Corporatization
# /wiki/Plantation_economy
# /wiki/Digital_economy
# /wiki/European_Union
# /wiki/Caddy_Adzuba
# /wiki/Jos%C3%A9_Andr%C3%A9s
# /wiki/Spanish_name
# /wiki/Judicial_titles
# /wiki/The_Right_Honourable
# /wiki/John_Abbott
# /wiki/Charles_Tupper
# /wiki/Roger_Stuart_Bacon
# /wiki/Donald_Cameron_(Nova_Scotia_premier)
# /wiki/Wayne_Fraser
# /wiki/Nova_Scotia_Liberal_Party
# /wiki/John_Turner
# /wiki/2006_Liberal_Party_of_Canada_leadership_election
# /wiki/St%C3%A9phane_Dion
# /wiki/Islamic_State_of_Iraq_and_the_Levant
# /wiki/Ministry_of_Justice_(Japan)
# /wiki/Penal_system_of_Japan
# /wiki/Yokosuka,_Kanagawa
# /wiki/Tsukuihama_Station
# /wiki/Oshiage_Station
# /wiki/Hikifune_Station
# /wiki/Horikiri_Station
# /wiki/Tobu_Railway
# /wiki/Tobu_8000_series
# /wiki/T%C5%8Dbu_Kiry%C5%AB_Line
# /wiki/Agatsuma_Line
# /wiki/Onsen
# /wiki/Ginzan_Onsen
# /wiki/Balneotherapy
# /wiki/Hydrotherapy
# /wiki/Traditional_healers_of_Southern_Africa
# /wiki/ISSN_(identifier)
# /wiki/ISO_31-10
# /wiki/ISO_860
# /wiki/ISO_11784_and_ISO_11785
# /wiki/ISO_639-6
# /wiki/ISO/IEC_8859-6
# /wiki/Xerox_Character_Code_Standard
# /wiki/%CE%A4
# /wiki/Torsion_of_a_curve
# /wiki/Frenet%E2%80%93Serret_formulas
# /wiki/Spinning_top
# /wiki/Maple
# /wiki/Wood_stain
# /wiki/Malus
# /wiki/Malus_halliana
# /wiki/Natural_Resources_Conservation_Service#Plants
# /wiki/Drainage_system_(agriculture)
# /wiki/National_Irrigation_Congress
# /wiki/Bill_Cody
# /wiki/Emperor_Norton
# /wiki/Modoc_people
# /wiki/Mohave_people
# /wiki/Milwaukee_Public_Museum
# /wiki/Miller_Brewing_Company
# /wiki/Ursus_Breweries
# /wiki/Timi%C8%99oara
# /wiki/Germans
# /wiki/Banking_in_Germany
# /wiki/Universal_banking
# /wiki/Money_creation
# /wiki/Greg_Mankiw
# /wiki/Austan_Goolsbee
# /wiki/Emergency_Banking_Act
# /wiki/Roosevelt_family
# /wiki/Second_Occupation_of_Cuba
# /wiki/Joseph_Willard_Roosevelt
# /wiki/Bard_College_at_Simon%27s_Rock
# /wiki/Roman_Mars
# /wiki/Public_Radio_Exchange
# /wiki/Family_Radio
# /wiki/Reading,_Pennsylvania
# /wiki/Pennsylvania
# /wiki/Pennsylvania_Department_of_General_Services
# /wiki/Government_of_Pennsylvania
# /wiki/Luzerne_County,_Pennsylvania
# /wiki/1972_United_States_presidential_election_in_Pennsylvania
# /wiki/1816_Pennsylvania%27s_9th_congressional_district_special_election
# /wiki/1950_United_States_House_of_Representatives_elections_in_Pennsylvania
# /wiki/Anthony_Cavalcante
# /wiki/James_E._Van_Zandt
# /wiki/John_C._Kunkel
# /wiki/William_A._Barrett
# /wiki/Wilson_D._Gillette
# /wiki/Francis_E._Walter
# /wiki/William_J._Green_Jr.
# /wiki/Pennsylvania
# /wiki/County_(United_States)
# /wiki/List_of_counties_in_Indiana
# /wiki/Posey_County
# /wiki/Michiana
# /wiki/Sports_in_Indiana
# /wiki/United_States_at_the_Parapan_American_Games
# /wiki/Tennis_in_the_United_States
# /wiki/Monica_Seles
# /wiki/2017_US_Open_%E2%80%93_Women%27s_singles
# /wiki/%C4%B0pek_Soylu
# /wiki/2017_US_Open_%E2%80%93_Women%27s_singles
# /wiki/Duan_Yingying
# /wiki/Agnieszka_Radwa%C5%84ska
# /wiki/Francesca_Gordigiani
# /wiki/Women%27s_Tennis_Association
# /wiki/WTA_125_tournaments
# /wiki/Han_Xinyun
# /wiki/Suzhou_Ladies_Open
# /wiki/Clearwater_Women%27s_Open
# /wiki/Berkeley_Tennis_Club_Challenge
# /wiki/Florida%27s_Sports_Coast_Open
# /wiki/Oeiras_Ladies_Open
# /wiki/Jinan_International_Open
# /wiki/United_Kingdom
# /wiki/Doi_(identifier)
# /wiki/ISBN
# /wiki/Book_swapping
# /wiki/Books_in_Italy
# /wiki/Adriatic_Veneti
# /wiki/Orders,_decorations,_and_medals_of_Italy
# /wiki/Orders,_decorations,_and_medals_of_Socialist_Republic_of_Romania
# /wiki/Orders,_decorations,_and_medals_of_Botswana
# /wiki/Orders,_decorations,_and_medals_of_Indonesia
# /wiki/Order_(distinction)
# /wiki/Order_of_merit
# /wiki/Lists_of_awards
# /wiki/Guinness_World_Records
# /wiki/Pedro_L%C3%B3pez_(serial_killer)
# /wiki/Pedophilia
# /wiki/PMID_(identifier)
# /wiki/R_(programming_language)
# /wiki/Rattle_GUI
# /wiki/Software_release_life_cycle
# /wiki/Proprietary_software
# /wiki/JavaScript
# /wiki/Server-side_JavaScript
# /wiki/Modernizr
# /wiki/Programmer
# /wiki/Bernoulli_number
# /wiki/Gottfried_Wilhelm_Leibniz
# /wiki/University_of_Altdorf
# /wiki/University
# /wiki/History_of_European_universities
# /wiki/Autonomy
# /wiki/German_language
# /wiki/List_of_states_in_the_Holy_Roman_Empire
# /wiki/Ernestine_duchies
# /wiki/House_of_Windsor
# /wiki/George_V
# /wiki/Leopold_von_Hoesch
# /wiki/Adolf_Hitler
# /wiki/Richard_Walther_Darr%C3%A9
# /wiki/Horst-Wessel-Lied
# /wiki/Jedna_si_jedina
# /wiki/Heil_dir_im_Siegerkranz
# /wiki/Kde_domov_m%C5%AFj#National_Anthem_of_Czechoslovakia_1918–1992
# /wiki/Anthem_of_Saint_Petersburg
# /wiki/List_of_British_anthems
# /wiki/Himno_di_K%C3%B2rsou
# /wiki/Salve_a_ti,_Nicaragua
# /wiki/The_Old_North_State_(song)
# /wiki/Hawai%CA%BBi_Pono%CA%BB%C4%AB
# /wiki/La_Dessalinienne
# /wiki/National_anthem_of_Anguilla
# /wiki/Florida_(Where_the_Sawgrass_Meets_the_Sky)
# /wiki/South_Florida_Sun-Sentinel
# /wiki/1926_Miami_hurricane
# /wiki/Hurricane_Ione
# /wiki/Hurricane_Audrey
# /wiki/North_American_T-28_Trojan
# /wiki/North_American_XB-70_Valkyrie
# /wiki/North_American_T-2_Buckeye
# /wiki/North_American_B-25_Mitchell
# /wiki/North_American_F-86D_Sabre
# /wiki/USAF
# /wiki/Operation_Northern_Watch
# /wiki/AGM-88_HARM
# /wiki/Royal_Australian_Air_Force
# /wiki/Operation_Okra
# /wiki/Ja%27Din_shootdown_incident
# /wiki/Foreign_fighters_in_the_Syrian_civil_war
# /wiki/Tweet_(social_media)
# /wiki/FlockDB
# /wiki/Twitter_trends
# /wiki/ISBN_(identifier)
# /wiki/ISO/IEC_8859-7
# /wiki/GEM_character_set
# /wiki/Kathryn_Strutynski
# /wiki/IMDOS
# /wiki/MS-DOS
# /wiki/FASTOPEN
# /wiki/Diskette
# /wiki/Boot_disk#Boot_floppies
# /wiki/Computer_file
# /wiki/Unix-like
# /wiki/FreeBSD
# /wiki/SCTP
# /wiki/RFC_(identifier)
# /wiki/Internet_Standard#Internet_Standards
# /wiki/Request_for_Comments
# /wiki/Steve_Crocker
# /wiki/Vint_Cerf
# /wiki/Gil_McVean
# /wiki/Sue_Ion
# /wiki/Three_Mile_Island_accident
# /wiki/Doi_(identifier)
# /wiki/ISO_9000
# /wiki/Shoe_size
# /wiki/SDMX
# /wiki/ISO_10303-22
# /wiki/Shoe_size
# /wiki/List_of_IEC_standards
# /wiki/Document_Style_Semantics_and_Specification_Language
# /wiki/Minimal_BASIC
# /wiki/Test_suite
# /wiki/Test_plan
# /wiki/ISBN_(identifier)
# /wiki/Bookcase
# /wiki/Folio
# /wiki/Oxford_University_Press
# /wiki/Blavatnik_School_of_Government
# /wiki/Oxford_University_W.A.F.C.
# /wiki/Christ_Church_Ground
# /wiki/Oxford_University_Press
# /wiki/Faculty_of_Philosophy,_University_of_Oxford
# /wiki/John_Hawthorne
# /wiki/Paul_Tillich
# /wiki/ISBN_(identifier)
# /wiki/MPEG-21
# /wiki/G.726
# /wiki/Theora
# /wiki/Mpxplay
# /wiki/MPEG_program_stream
# /wiki/Real-time_Transport_Protocol
# /wiki/Streaming_media
# /wiki/Broadcast_television_systems
# /wiki/Wayback_Machine
# /wiki/CanLII
# /wiki/Case_citation
# /wiki/Stephen_Breyer
# /wiki/Fannie_Lou_Hamer
# /wiki/J._Charles_Jones
# /wiki/Michael_Eric_Dyson
# /wiki/Michelle_Bernard
# /wiki/Al_Jazeera_Media_Network
# /wiki/Libya
# /wiki/Pan-Arabism
# /wiki/Six-Day_War
# /wiki/1947%E2%80%931948_civil_war_in_Mandatory_Palestine
# /wiki/Causes_of_the_1948_Palestinian_expulsion_and_flight
# /wiki/Eilabun_massacre
# /wiki/Balad_al-Shaykh_massacre
# /wiki/Israel
# /wiki/Japan
# /wiki/Taih%C5%8D_Code
# /wiki/Y%C5%8Dr%C5%8D_Code
# /wiki/Ishida_Mitsunari
# /wiki/Daitoku-ji
# /wiki/S%C5%8Dt%C5%8D
# /wiki/D%C5%8Dgen
# /wiki/Samantabhadra_Bodhisattva
# /wiki/Human_beings_in_Buddhism
# /wiki/Mahayana_sutras
# /wiki/Gandhari_language
# /wiki/Gauda%E2%80%93Kamarupa_languages
# /wiki/Prakrit
# /wiki/Indo-Aryan_languages
# /wiki/Sorani
# /wiki/ISBN_(identifier)
# /wiki/Digital_object_identifier
# /wiki/CrossRef
# /wiki/Article_discovery
# /wiki/Product_finder
# /wiki/Recommender_system
# /wiki/Algorithmic_radicalization
# /wiki/Social_bot
# /wiki/Infodemic
# /wiki/Media_multitasking
# /wiki/Digital_zombie
# /wiki/Media_(communication)
# /wiki/Electronic_media
# /wiki/Control_panel_(engineering)
# /wiki/Nuclear_power_plant
# /wiki/Massachusetts_Institute_of_Technology
# /wiki/Rhodes_Scholar
# /wiki/Rhodes_Trust
# /wiki/Wasim_Sajjad
# /wiki/Zulfikar_Ali_Bhutto
# /wiki/United_Nations_Security_Council
# /wiki/Six-Day_War
# /wiki/United_States_Navy
# /wiki/List_of_U.S._chemical_weapons_topics
# /wiki/Hispanics_in_the_United_States_Navy
# /wiki/Chu_Lai
# /wiki/23rd_Infantry_Division_(United_States)
# /wiki/1st_Infantry_Division_(United_States)
# /wiki/106th_Infantry_Division_(United_States)
# /wiki/70th_Infantry_Division_(United_States)
# /wiki/28th_Infantry_Division_(United_States)
# /wiki/Invasion_of_Normandy
# /wiki/Borneo_campaign
# /wiki/Military_history_of_the_Philippines_during_World_War_II
# /wiki/Anglo-Iraqi_War
# /wiki/John_Bagot_Glubb
# /wiki/Order_of_Saint_John_(chartered_1888)
# /wiki/Bailiff_Grand_Cross_of_the_Order_of_St_John
# /wiki/Order_of_the_British_Empire
# /wiki/Orders,_decorations,_and_medals_of_the_United_Kingdom
# /wiki/Jellalabad_Medals
# /wiki/India_General_Service_Medal_(1854)
# /wiki/Rhodesia_Medal
# /wiki/North_West_Canada_Medal
# /wiki/South_Africa_Medal_(1853)
# /wiki/Gold_Star_for_Bravery
# /wiki/King%27s_South_Africa_Medal
# /wiki/Arctic_Star
# /wiki/Medalje_vir_Troue_Diens
# /wiki/Silver_Service_Medal
# /wiki/Azanian_People%27s_Liberation_Army
# /wiki/Toyi-toyi
# /wiki/New_Republic_Party_(South_Africa)
# /wiki/Freedom_Charter
# /wiki/President_Street_Power_Station,_Johannesburg
# /wiki/South_African_Special_Forces
# /wiki/M23_rebellion
# /wiki/Democratic_Republic_of_the_Congo%E2%80%93Rwanda_relations
# /wiki/Rwandan_genocide
# /wiki/Viking_Press
# /wiki/RTL_(Luxembourgian_TV_channel)
# /wiki/Vatican_Radio
# /wiki/National_Communications_Network,_Guyana
# /wiki/Radio_France
# /wiki/China_National_Radio
# /wiki/Computer_network
# /wiki/Bluetooth
# /wiki/Spread_spectrum
# /wiki/SIGSALY
# /wiki/Embassy_of_the_United_States,_London
# /wiki/Embassy_of_Croatia,_London
# /wiki/High_Commission_of_Fiji,_London
# /wiki/List_of_diplomatic_missions_of_Kurdistan_Region
# /wiki/List_of_diplomatic_missions_of_Lebanon
# /wiki/Montevideo
# /wiki/Life_expectancy_at_birth
# /wiki/United_Nations
# /wiki/International_Decade_for_a_Culture_of_Peace_and_Non-Violence_for_the_Children_of_the_World
# /wiki/United_Nations_University
# /wiki/Bretton_Woods_system
# /wiki/Federal_Reserve_Bank_of_New_York
# /wiki/Federal_Reserve_Bank_of_Atlanta_Birmingham_Branch
# /wiki/Federal_Open_Market_Committee
# /wiki/Lender_of_last_resort
# /wiki/Money_supply
# /wiki/Shrinkflation
# /wiki/Hermann_Heinrich_Gossen
# /wiki/First_French_Empire
# /wiki/French_Revolutionary_Wars
# /wiki/Battle_of_Verdun_(1792)
# /wiki/Jean-Baptiste_Robert_Lindet
# /wiki/Claude_Bouthillier
# /wiki/Jean-Jacques_Amelot_de_Chaillou
# /wiki/Jean_Cruppi
# /wiki/Louis_Napol%C3%A9on_Lannes
# /wiki/Louis_Philippe_I
# /wiki/Louis-Gabriel_Suchet
# /wiki/War_in_the_Vend%C3%A9e
# /wiki/Coup_of_18_Fructidor
# /wiki/Fran%C3%A7ois-Nicolas_Vincent
# /wiki/Monarchy
# /wiki/Devolution
# /wiki/Tanzania
# /wiki/List_of_countries_by_GDP_(PPP)_per_capita
# /wiki/List_of_countries_by_percentage_of_population_living_in_poverty
# /wiki/Malaysia
# /wiki/Indonesia
# /wiki/Egypt
# /wiki/Tennis
# /wiki/Sony_Ericsson_Open
# /wiki/Canada
# /wiki/Media_of_Canada
# /wiki/CMT_(Canada)
# /wiki/Nick_Jr._Channel
# /wiki/KOL_Secret_Slumber_Party
# /wiki/My_Little_Pony_(TV_series)
# /wiki/The_Marvel_Action_Hour
# /wiki/Ten_Rings_(organization)
# /wiki/Immortality
# /wiki/Paul_the_Apostle
# /wiki/John_Fisher
# /wiki/Marie-Dominique_Chenu
# /wiki/High_Middle_Ages
# /wiki/Cradle_of_civilization
# /wiki/Yamhad
# /wiki/Ekallatum
# /wiki/Shubat-Enlil
# /wiki/Geographic_coordinate_system
# /wiki/Antarctica
# /wiki/Antarctica
# /wiki/Biomedical_scientist
# /wiki/Scientist
# /wiki/Mammalogy
# /wiki/Xenobiology
# /wiki/S2CID_(identifier)
# /wiki/Academic_journal_publishing_reform
# /wiki/Serials_crisis
# /wiki/Publish_or_perish
# /wiki/List_of_open-access_journals
# /wiki/Journal_of_Machine_Learning_Research
# /wiki/Academic_publishing
# /wiki/Grey_literature
# /wiki/Scientific_writing
# /wiki/Pamphlet
# /wiki/Marketing
# /wiki/Conglomerate_(company)
# /wiki/Sony_Pictures_Entertainment
# /wiki/Crunchyroll_LLC
# /wiki/Dallas
# /wiki/Ellis_County,_Texas
# /wiki/Cooke_County,_Texas
# /wiki/Edinburg,_Texas
# /wiki/Snyder,_Texas
# /wiki/Tilden,_Texas
# /wiki/Austin,_Texas
# /wiki/Longview,_Texas
# /wiki/Leakey,_Texas
# /wiki/Beaumont,_Texas
# /wiki/Edgar_Winter
# /wiki/The_Woodstock_Experience
# /wiki/In_Concert_(Janis_Joplin_album)
# /wiki/The_Lost_Tapes_(Big_Brother_and_the_Holding_Company_album)
# /wiki/Live_at_Winterland_%2768
# /wiki/Sam_Andrew
# /wiki/Taft,_California
# /wiki/Cawelo,_California
# /wiki/Gold_Town,_California
# /wiki/Garlock,_California
# /wiki/Wasco,_California
# /wiki/Tejon_Indian_Tribe_of_California
# /wiki/Indian_reservation
# /wiki/List_of_federally_recognized_tribes
# /wiki/Comanche_Wars
# /wiki/Great_Plains
# /wiki/Mass_surveillance_in_the_United_States
# /wiki/Illegal_immigration_to_the_United_States
# /wiki/American_Competitiveness_in_the_21st_Century_Act
# /wiki/Oslo_I_Accord
# /wiki/Battle_of_Nablus
# /wiki/Oslo_Accords
# /wiki/Yahya_Ayyash
# /wiki/Acetone_peroxide
# /wiki/Detonation_velocity
# /wiki/Speed_of_sound
# /wiki/Transverse_wave
# /wiki/List_of_string_instruments
# /wiki/Appalachian_dulcimer
# /wiki/Hummel_(instrument)
# /wiki/Swedish_bagpipes
# /wiki/Riksspelman
# /wiki/Tune_(folk_music)
# /wiki/Grammy_Award_for_Best_Traditional_Folk_Album
# /wiki/Bill_Morrissey
# /wiki/Inside_(Bill_Morrissey_album)
# /wiki/Chicago_Tribune
# /wiki/Gangs_in_Chicago
# /wiki/Almighty_Vice_Lord_Nation
# /wiki/Ghetto_Brothers
# /wiki/Sister_Ping
# /wiki/Fran%C3%A7ois_Le_Clerc
# /wiki/Jean_Lafitte
# /wiki/Sandokan
# /wiki/Aegean_Sea_anti-piracy_operations_of_the_United_States
# /wiki/Richard_Glover_(pirate)
# /wiki/Uskoks
# /wiki/Chepo_expedition
# /wiki/North_Star_affair
# /wiki/1985_Lahad_Datu_ambush
# /wiki/Kuala_Lumpur
# /wiki/Kabul
# /wiki/Kabul%E2%80%93Darulaman_Tramway
# /wiki/Kabul
# /wiki/Wayback_Machine
# /wiki/Heritrix
# /wiki/Internet_Archive_Scholar
# /wiki/Internet_Archive#Audio_collection
# /wiki/Machinima,_Inc.
# /wiki/Yahoo!_News
# /wiki/Cheddar_(TV_channel)
# /wiki/NHK_World-Japan
# /wiki/NewsNet
# /wiki/UPN
# /wiki/Harrisburg,_Pennsylvania
# /wiki/Snyder_County,_Pennsylvania
# /wiki/1960_United_States_census
# /wiki/United_States_Census_Bureau
# /wiki/Joseph_Adna_Hill
# /wiki/William_Gemmell_Cochran
# /wiki/David_Hand_(statistician)
# /wiki/Henry_Wynn
# /wiki/Harry_Campion
# /wiki/Francis_Ysidro_Edgeworth
# /wiki/Carnegie_School
# /wiki/Abraham_Charnes
# /wiki/Harry_Markowitz
# /wiki/Bachelor_of_Philosophy
# /wiki/Critical_thinking
# /wiki/Education_in_Seychelles
# /wiki/Seychellois_rupee
# /wiki/Digital_rupee
# /wiki/Portuguese_Indian_rupia
# /wiki/Tin
# /wiki/Tin_mining
# /wiki/Indonesia
# /wiki/Overseas_collectivity
# /wiki/Communes_of_France
# /wiki/Communes_of_the_Cher_department
# /wiki/Contres,_Cher
# /wiki/Aubigny-sur-N%C3%A8re
# /wiki/Ch%C3%A2teauneuf-sur-Cher
# /wiki/Grossouvre
# /wiki/Charly,_Cher
# /wiki/Saint-L%C3%A9ger-le-Petit
# /wiki/Savigny-en-Sancerre
# /wiki/Levet,_Cher
# /wiki/Vereaux
# /wiki/Jars,_Cher
# /wiki/Jouet-sur-l%27Aubois
# /wiki/Central_European_Time
# /wiki/Hungary
# /wiki/Flag_of_the_Organization_of_Turkic_States
# /wiki/Flag_of_Kyrgyzstan
# /wiki/Kyrgyz_cuisine
# /wiki/Cuisine_of_Kyrgyzstan
# /wiki/Burmese_cuisine
# /wiki/Mont_(food)
# /wiki/Htanthi_mont
# /wiki/Fruit_preserve
# /wiki/Vincotto
# /wiki/Honey_dill
# /wiki/Crema_(dairy_product)
# /wiki/Pickled_fruit
# /wiki/Pindjur
# /wiki/MSG
# /wiki/Malari_incident
# /wiki/Chinese_Immigration_Act_of_1885
# /wiki/Canadian_citizen
# /wiki/Immigration_to_Canada
# /wiki/Toronto_Star
# /wiki/Tanya_Talaga
# /wiki/ISSN_(identifier)
# /wiki/ISO_3977
# /wiki/ISO_31-0
# /wiki/Hazard_symbol#Ionizing_radiation_symbol
# /wiki/Notices_to_mariners
# /wiki/Australian_Sailing_magazine
# /wiki/Surry_Hills
# /wiki/Postcodes_in_Australia
# /wiki/Postal_codes_in_New_Caledonia
# /wiki/L%C3%A9paud
# /wiki/Trois-Fonds
# /wiki/Saint-Chabrais
# /wiki/Saint-%C3%89loi,_Creuse
# /wiki/Geographic_coordinate_system
# /wiki/Jacopo_d%27Angelo
# /wiki/Manuel_II_Palaiologos
# /wiki/Valerian_(emperor)
# /wiki/%27Apepi
# /wiki/Nepherites_II
# /wiki/Amenemnisu
# /wiki/Thirtieth_Dynasty_of_Egypt#Family_tree
# /wiki/Shoshenq_VII
# /wiki/Thirtieth_Dynasty_of_Egypt#Family_tree
# /wiki/Sewadjkare_III
# /wiki/Twenty-first_Dynasty_of_Egypt
# /wiki/Eleventh_Dynasty_of_Egypt
# /wiki/Second_Intermediate_Period_of_Egypt
# /wiki/Thirtieth_Dynasty_of_Egypt
# /wiki/Sheshi
# /wiki/Tiu_(pharaoh)
# /wiki/Neferirkare_Kakai
# /wiki/Double_Falcon
# /wiki/G%C3%BCnter_Dreyer
# /wiki/Carbon-dated
# /wiki/Iranian_calendars
# /wiki/Cyrus_the_Great
# /wiki/Arsames
# /wiki/Artemisia_II_of_Caria
# /wiki/Caria
# /wiki/Latmus
# /wiki/Alalakh
# /wiki/Sebaste_(Phrygia)
# /wiki/Domuztepe
# /wiki/Callipolis_(Caria)
# /wiki/Sirkanos
# /wiki/Aureliopolis_in_Lydia
# /wiki/Heraclea_Pontica
# /wiki/Greco-Buddhist_monasticism
# /wiki/Threefold_Training
# /wiki/Miracles_of_Gautama_Buddha
# /wiki/Dhamma#Buddhism
# /wiki/Gunasthana
# /wiki/S%C4%81m%C4%81yika
# /wiki/Champat_Rai_Jain
# /wiki/Yashovijaya
# /wiki/Ratnaprabhasuri
# /wiki/Deva_(Jainism)
# /wiki/Shikharji
# /wiki/Giridih_district
# /wiki/National_Highway_19_(India)
# /wiki/National_Highway_24_(India)
# /wiki/National_Highway_427_(India)
# /wiki/National_Highway_702_(India)
# /wiki/National_Highway_122A_(India)
# /wiki/National_Highway_354E_(India)
# /wiki/National_Highway_165_(India)
# /wiki/National_Highway_510_(India)
# /wiki/National_Highway_954_(India)
# /wiki/National_Highway_309A_(India)
# /wiki/National_Highway_519_(India)
# /wiki/National_Highway_369E_(India)
# /wiki/National_Highway_703_(India)
# /wiki/National_Highway_64_(India)
# /wiki/National_Highway_561_(India)
# /wiki/National_Highway_127_(India)
# /wiki/National_Highway_527B_(India)
# /wiki/National_Highway_147E_(India)
# /wiki/National_Highway_717_(India)
# /wiki/National_Highway_306_(India)
# /wiki/National_Highway_363_(India)
# /wiki/National_Highway_344B_(India)
# /wiki/National_Highway_328_(India)
# /wiki/National_Highway_168A_(India)
# /wiki/National_Highway_218_(India)
# /wiki/Panipat_Elevated_Expressway
# /wiki/National_Highway_339_(India)
# /wiki/National_Highway_137_(India)
# /wiki/National_Highway_727AA_(India)
# /wiki/National_Highway_331_(India)
# /wiki/National_Highway_206_(India)
# /wiki/National_Highway_317_(India)
# /wiki/National_Highway_31_(India)
# /wiki/National_Highway_465_(India)
# /wiki/National_Highway_336_(India)
# /wiki/National_Highway_717B_(India)
# /wiki/National_Highway_62_(India)
# /wiki/Abohar
# /wiki/Time_zone
# /wiki/Mental_chronometry
# /wiki/Jensen_Box
# /wiki/Odd_Man_Out_test
# /wiki/Jensen_box
# /wiki/W._E._Hick
# /wiki/Cognition_and_Brain_Sciences_Unit
# /wiki/England
# /wiki/British%E2%80%93Irish_Parliamentary_Assembly
# /wiki/Names_of_the_British_Isles
# /wiki/Spyridon_Lambros
# /wiki/Dimitrios_Maximos
# /wiki/Charalampos_Christopoulos
# /wiki/Georgios_Modis
# /wiki/Alekos_Papadopoulos
# /wiki/Wall_Street_Journal
# /wiki/Politico
# /wiki/Associated_Press
# /wiki/Pearson_plc
# /wiki/BBC_Local_Radio
# /wiki/BBC_Television
# /wiki/List_of_radio_stations_in_the_United_Kingdom#RSL_stations
# /wiki/Hits_Radio#Stations
# /wiki/Hits_Radio_Pride
# /wiki/Smash_Hits_Radio
# /wiki/TV_Choice
# /wiki/3C_(radio)
# /wiki/Country_Hits_Radio
# /wiki/Mark_Crossley_(broadcaster)
# /wiki/BBC_Sounds
# /wiki/BBC_Radio_Jersey
# /wiki/Television_Centre,_London
# /wiki/Westminster
# /wiki/Wimbledon,_London
# /wiki/Tommy_Steele
# /wiki/Adelphi_Theatre
# /wiki/Ashcroft_Theatre
# /wiki/Nederlander_Organization
# /wiki/The_Grove_of_Anaheim
# /wiki/BottleRock_Napa_Valley
# /wiki/Snoop_Dogg
# /wiki/Tha_Eastsidaz
# /wiki/Malice_n_Wonderland
# /wiki/R._Kelly
# /wiki/Mamacita_(Public_Announcement_song)
# /wiki/Body_Bumpin%27_(Yippie-Yi-Yo)
# /wiki/Hey_Love_(Can_I_Have_a_Word)
# /wiki/List_of_awards_and_nominations_received_by_R._Kelly
# /wiki/That%27s_That
# /wiki/Home_Alone_(song)
# /wiki/Official_Charts_Company
# /wiki/List_of_UK_singles_chart_number_ones_of_the_1980s
# /wiki/Music_download
# /wiki/Comparison_of_digital_music_stores
# /wiki/MP3
# /wiki/MPEG-2#Systems
# /wiki/JVC_Kenwood
# /wiki/Canon_Inc.
# /wiki/Mitsubishi_Electric
# /wiki/SMC_Corporation
# /wiki/Renesas_Electronics
# /wiki/LS-R
# /wiki/Hitachi_Tower
# /wiki/Nissin_Kogyo
# /wiki/Honda_CR-Z
# /wiki/HPD_ARX-04b
# /wiki/Honda_NSX_(second_generation)
# /wiki/2020_IMSA_SportsCar_Championship
# /wiki/2010_American_Le_Mans_Series
# /wiki/Austria
# /wiki/Counter-Reformation
# /wiki/German_literature#German_Renaissance_and_Reformation
# /wiki/Barthold_Heinrich_Brockes
# /wiki/Balthasar_Denner
# /wiki/Brockes_Passion
# /wiki/Classical_music
# /wiki/Music_of_Western_Sahara
# /wiki/Music_of_Djibouti
# /wiki/Music_of_Ghana
# /wiki/Music_of_the_Comoros
# /wiki/Constitution_of_the_Comoros
# /wiki/Elections_in_the_Comoros
# /wiki/List_of_political_parties_in_the_Comoros
# /wiki/Anti-Federalism
# /wiki/New_York_(state)
# /wiki/South_Fork_(Long_Island)
# /wiki/West_Islip,_New_York
# /wiki/Brightwaters,_New_York
# /wiki/ZIP_code
# /wiki/Sectional_center_facility
# /wiki/Shreveport,_Louisiana
# /wiki/Village_(Louisiana)
# /wiki/Special-purpose_district
# /wiki/Hospital
# /wiki/Asclepius
# /wiki/ISBN_(identifier)
# /wiki/European_Article_Number
# /wiki/POSTNET
# /wiki/Express_mail
# /wiki/Postal_administration
# /wiki/Guernsey_Post
# /wiki/Jersey_Post
# /wiki/Geology_of_Jersey
# /wiki/Scandian_orogeny
# /wiki/Tectonic_subsidence
# /wiki/Fault_(geology)#Dip-slip_faults
# /wiki/Detachment_fault
# /wiki/Cataclasite
# /wiki/Breccia
# /wiki/Tufa
# /wiki/Metapelite
# /wiki/Teschenite
# /wiki/Jaspillite
# /wiki/Gossan
# /wiki/Rhomb_porphyry
# /wiki/Wackestone
# /wiki/Marl
# /wiki/Gossan
# /wiki/Jasperoid
# /wiki/Wehrlite
# /wiki/Theralite
# /wiki/Essexite
# /wiki/Rubidium
# /wiki/NFPA_704
# /wiki/Helium
# /wiki/Uranium
# /wiki/Radioactive_waste
# /wiki/Doi_(identifier)
# /wiki/Ars_Technica
# /wiki/Warner_Bros._Discovery
# /wiki/List_of_libraries_owned_by_Warner_Bros._Discovery
# /wiki/Avalanche_Software
# /wiki/Hanna-Barbera_Studios_Europe
# /wiki/Cartoonito_(Portuguese_TV_channel)
# /wiki/Boomerang_(Australian_TV_channel)
# /wiki/Discovery_Kids_(Indian_TV_channel)
# /wiki/Cooking_Channel_(Canadian_TV_channel)
# /wiki/FIA_World_Endurance_Championship
# /wiki/Acrobatic_Gymnastics_World_Championships
# /wiki/Moscow
# /wiki/Institute_for_Theoretical_and_Experimental_Physics
# /wiki/Sergei_Gukov
# /wiki/Max_Planck_Institute_for_Mathematics
# /wiki/Dynamical_Systems
# /wiki/Measure_theory
# /wiki/Area
# /wiki/Euclidean_geometry
# /wiki/Transitive_property
# /wiki/Reflexive_relation#Irreflexive
# /wiki/Partially_ordered_set
# /wiki/Order_topology_(functional_analysis)
# /wiki/Well-order
# /wiki/Order_type
# /wiki/Positive_cone_of_a_partially_ordered_group
# /wiki/Cyclically_ordered_group
# /wiki/MR_(identifier)
# /wiki/Web_of_Science
# /wiki/Article-level_metrics
# /wiki/Academic_publishing
# /wiki/Professional_magazines
# /wiki/Periodical
# /wiki/Magazine
# /wiki/St._Anthony_Messenger
# /wiki/Franciscan_Media
# /wiki/Cincinnati
# /wiki/Ensemble_Theatre_Cincinnati
# /wiki/Geographic_coordinate_system
# /wiki/Altitude
# /wiki/Doi_(identifier)
# /wiki/ISO_31-3
# /wiki/Whirlpool_(hash_function)
# /wiki/PDF/X
# /wiki/ISO/IEC_42010
# /wiki/MPEG-2
# /wiki/WebM
# /wiki/Sorenson_Media
# /wiki/Video_coding_format
# /wiki/Group_4_compression
# /wiki/Bink_Video
# /wiki/H.263
# /wiki/Apple_ProRes
# /wiki/QOI_(image_format)
# /wiki/3GP_and_3G2
# /wiki/JPEG_XS
# /wiki/Differential_pulse-code_modulation
# /wiki/Analog_signal
# /wiki/Erna_Schneider_Hoover
# /wiki/Beacon#For_defensive_communications
# /wiki/Emergency_vehicle_lighting
# /wiki/National_Highways_traffic_officer
# /wiki/Kingston_Bridge,_Glasgow
# /wiki/Kingston,_Glasgow
# /wiki/Riddrie
# /wiki/Emergency_medical_services_in_the_United_Kingdom
# /wiki/Emergency_medical_services_in_South_Africa
# /wiki/Medical_guideline
# /wiki/Specificity_(tests)
# /wiki/Cohort_study
# /wiki/Monotone_likelihood_ratio
# /wiki/Control_chart
# /wiki/Central_tendency
# /wiki/Nonparametric_regression
# /wiki/Errors_and_residuals
# /wiki/Van_der_Waerden_test
# /wiki/Random_assignment
# /wiki/Uniformly_most_powerful_test
# /wiki/Contingency_table
# /wiki/Rao%E2%80%93Blackwell_theorem
# /wiki/Idempotent
# /wiki/Cambridge_University_Press
# /wiki/Derek_Barton
# /wiki/Richard_Smalley
# /wiki/Hans_von_Euler-Chelpin
# /wiki/Harold_Urey
# /wiki/Val_Logsdon_Fitch
# /wiki/Steven_Weinberg
# /wiki/Hannes_Alfv%C3%A9n
# /wiki/Theodor_W._H%C3%A4nsch
# /wiki/Anton_Zeilinger
# /wiki/Burton_Richter
# /wiki/Donald_A._Glaser
# /wiki/Nobel_Prize_in_Physics
# /wiki/Walter_Houser_Brattain
# /wiki/Robert_Brattain
# /wiki/Shell_Development_Company
# /wiki/Peet%27s_Coffee
# /wiki/Tropical_Smoothie_Cafe
# /wiki/Wraps
# /wiki/Paratha
# /wiki/Jalebi
# /wiki/Khash_(dish)
# /wiki/Feta
# /wiki/United_Kingdom
# /wiki/Formula_One
# /wiki/Canadian_Tire_Motorsport_Park
# /wiki/Le_Mans_Prototype#LMP3
# /wiki/Formula_C_(SCCA)
# /wiki/Supercars_Championship
# /wiki/Erebus_Motorsport
# /wiki/Perth_360
# /wiki/Ford_Sierra_RS_Cosworth
# /wiki/1987_World_Touring_Car_Championship
# /wiki/Ford_Sierra_RS_Cosworth
# /wiki/France
# /wiki/Napoleonic_Wars_casualties
# /wiki/Sarmatism
# /wiki/Conservatism#Finland
# /wiki/Habsburg_monarchy
# /wiki/Holy_Roman_Emperor
# /wiki/House_of_Habsburg-Lorraine
# /wiki/Olelkovich
# /wiki/Algirdas
# /wiki/Vygantas
# /wiki/Kernav%C4%97
# /wiki/ISBN_(identifier)
# /wiki/Prolog
# /wiki/ISO_31
# /wiki/ISO_8583
# /wiki/ASMO_449
# /wiki/International_Bank_Account_Number
# /wiki/ISO_31-4
# /wiki/ISO_668
# /wiki/PDF
# /wiki/ISO/IEC_TR_12182
# /wiki/IEC_TC_25
# /wiki/ISO/IEC_JTC_1/SC_31_Automatic_identification_and_data_capture_techniques
# /wiki/Automatic_identification_and_data_capture
# /wiki/Automatic_number-plate_recognition
# /wiki/OpenALPR
# /wiki/C%2B%2B
# /wiki/C%2B%2B23
# /wiki/C_(programming_language)
# /wiki/Xojo
# /wiki/GRASS_(programming_language)
# /wiki/XBasic
# /wiki/XVT
# /wiki/PascalABC.NET
# /wiki/AppCode
# /wiki/InfoQ
# /wiki/Data_set
# /wiki/Statistics
# /wiki/List_of_open_source_statistical_packages
# /wiki/Perl
# /wiki/Unlicense
# /wiki/Gratis_versus_libre
# /wiki/Python_License
# /wiki/Comparison_of_free_and_open-source_software_licences#Approvals
# /wiki/Fedora_Project
# /wiki/Software_package_(installation)
# /wiki/Binary_repository_manager
# /wiki/Logic_in_computer_science
# /wiki/Inference
# /wiki/Legal_positivism
# /wiki/Naturalism_(philosophy)
# /wiki/Philosophy_of_archaeology
# /wiki/Archaeological_site
# /wiki/Traditionalist_School_(perennialism)
# /wiki/A._K._Saran
# /wiki/El%C3%A9mire_Zolla
# /wiki/United_Kingdom
# /wiki/ISBN_(identifier)
# /wiki/DICOM
# /wiki/Voreen
# /wiki/Crime_mapping
# /wiki/Scientific_visualization
# /wiki/Lawrence_J._Rosenblum
# /wiki/Leland_Wilkinson
# /wiki/SPSS
# /wiki/Acquisition_of_the_IBM_PC_business_by_Lenovo
# /wiki/ThinkPad_R_series
# /wiki/ThinkPad_Tablet_2
# /wiki/HP_Spectre
# /wiki/Haswell_(microarchitecture)
# /wiki/Alder_Lake
# /wiki/Tremont_(microarchitecture)
# /wiki/List_of_Intel_Core_i7_processors
# /wiki/Direct_Media_Interface
# /wiki/USB
# /wiki/Peripheral
# /wiki/Supervised_learning
# /wiki/K-nearest_neighbors_algorithm
# /wiki/Linear_discriminant_analysis
# /wiki/Partial_correlation
# /wiki/Multivariate_analysis_of_variance
# /wiki/Bayes_estimator
# /wiki/Bayesian_model_averaging
# /wiki/Statistical_learning_theory
# /wiki/Multimodal_learning
# /wiki/Quantum_machine_learning
# /wiki/S2CID_(identifier)
# /wiki/Electronic_publishing
# /wiki/Working_paper
# /wiki/Scientific_writing
# /wiki/Eigenfactor
# /wiki/ISSN_(identifier)
# /wiki/ISO_8601
# /wiki/Nuclear_timescale
# /wiki/Olympiad
# /wiki/Winter_Olympic_Games
# /wiki/South_Korea_at_the_Olympics
# /wiki/South_Korea
# /wiki/Kim_Jong-il
# /wiki/7th_Central_Auditing_Commission_of_the_Workers%27_Party_of_Korea
# /wiki/8th_Politburo_of_the_Workers%27_Party_of_Korea
# /wiki/Kapsan_Faction_Incident
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/ISO/IEC_8859-2
# /wiki/%C5%A2
# /wiki/Spread_of_the_Latin_script
# /wiki/Cumae
# /wiki/Temple_of_Zeus,_Olympia
# /wiki/Diadochi
# /wiki/Neoptolemus_(general)
# /wiki/Bactria
# /wiki/Sampul_tapestry
# /wiki/Pastrana_Tapestries
# /wiki/%C3%96verhogdal_tapestries
# /wiki/Royal_Tapestry_Factory
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 14
#      12 newArticle = links[random.randint(0, len(links)-1)].attrs['href']
#      13 print(newArticle)
# ---> 14 links = getLinks(newArticle)
#
# Cell In[12], line 6, in getLinks(articleUrl)
#       5 def getLinks(articleUrl):
# ----> 6     html = urlopen('http://en.wikipedia.org{}'.format(articleUrl))
#       7     bs = BeautifulSoup(html, 'html.parser')
#       8     return bs.find('div', {'id': 'bodyContent'}).find_all('a', href=re.compile('^(/wiki/)((?!:).)*$'))
#
# File c:\Python312\Lib\urllib\request.py:215, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213 else:
#     214     opener = _opener
# --> 215 return opener.open(url, data, timeout)
#
# File c:\Python312\Lib\urllib\request.py:521, in OpenerDirector.open(self, fullurl, data, timeout)
#     519 for processor in self.process_response.get(protocol, []):
#     520     meth = getattr(processor, meth_name)
# --> 521     response = meth(req, response)
#     523 return response
#
# File c:\Python312\Lib\urllib\request.py:630, in HTTPErrorProcessor.http_response(self, request, response)
#     627 # According to RFC 2616, "2xx" code indicates that the client's
#     628 # request was successfully received, understood, and accepted.
#     629 if not (200 <= code < 300):
# --> 630     response = self.parent.error(
#     631         'http', request, response, code, msg, hdrs)
#     633 return response
#
# File c:\Python312\Lib\urllib\request.py:553, in OpenerDirector.error(self, proto, *args)
#     551     http_err = 0
#     552 args = (dict, proto, meth_name) + args
# --> 553 result = self._call_chain(*args)
#     554 if result:
#     555     return result
#
# File c:\Python312\Lib\urllib\request.py:492, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     490 for handler in handlers:
#     491     func = getattr(handler, meth_name)
# --> 492     result = func(*args)
#     493     if result is not None:
#     494         return result
#
# File c:\Python312\Lib\urllib\request.py:745, in HTTPRedirectHandler.http_error_302(self, req, fp, code, msg, headers)
#     742 fp.read()
#     743 fp.close()
# --> 745 return self.parent.open(new, timeout=req.timeout)
#
# File c:\Python312\Lib\urllib\request.py:515, in OpenerDirector.open(self, fullurl, data, timeout)
#     512     req = meth(req)
#     514 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 515 response = self._open(req, data)
#     517 # post-process response
#     518 meth_name = protocol+"_response"
#
# File c:\Python312\Lib\urllib\request.py:532, in OpenerDirector._open(self, req, data)
#     529     return result
#     531 protocol = req.type
# --> 532 result = self._call_chain(self.handle_open, protocol, protocol +
#     533                           '_open', req)
#     534 if result:
#     535     return result
#
# File c:\Python312\Lib\urllib\request.py:492, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     490 for handler in handlers:
#     491     func = getattr(handler, meth_name)
# --> 492     result = func(*args)
#     493     if result is not None:
#     494         return result
#
# File c:\Python312\Lib\urllib\request.py:1392, in HTTPSHandler.https_open(self, req)
#    1391 def https_open(self, req):
# -> 1392     return self.do_open(http.client.HTTPSConnection, req,
#    1393                         context=self._context)
#
# File c:\Python312\Lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1346     except OSError as err: # timeout error
#    1347         raise URLError(err)
# -> 1348     r = h.getresponse()
#    1349 except:
#    1350     h.close()
#
# File c:\Python312\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File c:\Python312\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File c:\Python312\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File c:\Python312\Lib\socket.py:708, in SocketIO.readinto(self, b)
#     706 while True:
#     707     try:
# --> 708         return self._sock.recv_into(b)
#     709     except timeout:
#     710         self._timeout_occurred = True
#
# File c:\Python312\Lib\ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Python312\Lib\ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# A way to avoid explore the same page twice

# %%
pages = set()
def getLinks(pageUrl):
    html = urlopen('http://en.wikipedia.org{}'.format(pageUrl))
    bs = BeautifulSoup(html, 'html.parser')

    for link in bs.find_all('a', href=re.compile('^(/wiki/)')): # Al no tener el $ al final indica que sea todos los /wiki/ de la pagina
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages: # Means is a new page
                newPage = link.attrs['href']
                print(newPage)
                pages.add(newPage)
                getLinks(newPage)
       
getLinks('')
# Out:
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_upload_wizard
# /wiki/Special:Search
# /wiki/Special:MyContributions
# /wiki/Special:MyTalk
# /wiki/Special:WhatLinksHere/User_talk:2806:261:486:7AE:847E:59FE:A0B8:B5FF
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[7], line 14
#      11                 pages.add(newPage)
#      12                 getLinks(newPage)
# ---> 14 getLinks('')
#
# Cell In[7], line 12, in getLinks(pageUrl)
#      10 print(newPage)
#      11 pages.add(newPage)
# ---> 12 getLinks(newPage)
#
# Cell In[7], line 12, in getLinks(pageUrl)
#      10 print(newPage)
#      11 pages.add(newPage)
# ---> 12 getLinks(newPage)
#
#     [... skipping similar frames: getLinks at line 12 (11 times)]
#
# Cell In[7], line 12, in getLinks(pageUrl)
#      10 print(newPage)
#      11 pages.add(newPage)
# ---> 12 getLinks(newPage)
#
# Cell In[7], line 3, in getLinks(pageUrl)
#       2 def getLinks(pageUrl):
# ----> 3     html = urlopen('http://en.wikipedia.org{}'.format(pageUrl))
#       4     bs = BeautifulSoup(html, 'html.parser')
#       6     for link in bs.find_all('a', href=re.compile('^(/wiki/)')): # Al no tener el $ al final indica que sea todos los /wiki/ de la pagina
#
# File c:\Users\Carlos Ramirez\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File c:\Users\Carlos Ramirez\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File c:\Users\Carlos Ramirez\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     631 # According to RFC 2616, "2xx" code indicates that the client's
#     632 # request was successfully received, understood, and accepted.
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File c:\Users\Carlos Ramirez\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:557, in OpenerDirector.error(self, proto, *args)
#     555     http_err = 0
#     556 args = (dict, proto, meth_name) + args
# --> 557 result = self._call_chain(*args)
#     558 if result:
#     559     return result
#
# File c:\Users\Carlos Ramirez\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File c:\Users\Carlos Ramirez\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:749, in HTTPRedirectHandler.http_error_302(self, req, fp, code, msg, headers)
#     746 fp.read()
#     747 fp.close()
# --> 749 return self.parent.open(new, timeout=req.timeout)
#
# File c:\Users\Carlos Ramirez\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File c:\Users\Carlos Ramirez\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     631 # According to RFC 2616, "2xx" code indicates that the client's
#     632 # request was successfully received, understood, and accepted.
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File c:\Users\Carlos Ramirez\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:563, in OpenerDirector.error(self, proto, *args)
#     561 if http_err:
#     562     args = (dict, 'default', 'http_error_default') + orig_args
# --> 563     return self._call_chain(*args)
#
# File c:\Users\Carlos Ramirez\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File c:\Users\Carlos Ramirez\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:643, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     642 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 404: Not Found

# %% [markdown]
# Crawlers for collect data

# %%
pages = set()
def getLinks(pageUrl):
    html = urlopen('http://en.wikipedia.org{}'.format(pageUrl))
    bs = BeautifulSoup(html, 'html.parser')
    try:
        print(bs.h1.get_text()) # Access to title
        print(bs.find(id ='mw-content-text').find_all('p')[0].prettify()) # Access to the first paragraph
        print(bs.find(id='ca-edit').find('span')
             .find('a').attrs['href'].prettify())# Get Edit links
    except AttributeError:
        print("The page is missing something! Continuing")
        
    for link in bs.find_all('a', href=re.compile('^(/wiki/)')):
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
                newPage = link.attrs['href']
                print('-'*20)
                print(newPage)
                pages.add(newPage)
                getLinks(newPage)
getLinks('')
# Out:
# Main Page
# <p>
#  The
#  <b>
#   <a href="/wiki/UEFA_Euro_2004_final" title="UEFA Euro 2004 final">
#    UEFA Euro 2004 final
#   </a>
#  </b>
#  was the final match of
#  <a href="/wiki/UEFA_Euro_2004" title="UEFA Euro 2004">
#   Euro 2004
#  </a>
#  , the 12th
#  <a href="/wiki/UEFA_European_Championship" title="UEFA European Championship">
#   European Championship
#  </a>
#  , organised by
#  <a href="/wiki/UEFA" title="UEFA">
#   UEFA
#  </a>
#  for the senior men's national
#  <a href="/wiki/Association_football" title="Association football">
#   association football
#  </a>
#  teams of its member associations. The match was played at the
#  <a href="/wiki/Est%C3%A1dio_da_Luz" title="Estádio da Luz">
#   Estádio da Luz
#  </a>
#  in
#  <a href="/wiki/Lisbon" title="Lisbon">
#   Lisbon
#  </a>
#  , Portugal, and contested by
#  <a href="/wiki/Portugal_national_football_team" title="Portugal national football team">
#   Portugal
#  </a>
#  and
#  <a href="/wiki/Greece_national_football_team" title="Greece national football team">
#   Greece
#  </a>
#  . The two defences ensured that goal-scoring opportunities were limited, and the score was
#  <span class="nowrap">
#   0–0
#  </span>
#  at half-time. Greece scored the only goal of the match after 57 minutes when
#  <a href="/wiki/Angelos_Basinas" title="Angelos Basinas">
#   Angelos Basinas
#  </a>
#  took a
#  <a href="/wiki/Corner_kick" title="Corner kick">
#   corner kick
#  </a>
#  to
#  <a href="/wiki/Angelos_Charisteas" title="Angelos Charisteas">
#   Angelos Charisteas
#  </a>
#  , who sent a
#  <a href="/wiki/Header_(association_football)" title="Header (association football)">
#   header
#  </a>
#  past goalkeeper
#  <a href="/wiki/Ricardo_(footballer,_born_1976)" title="Ricardo (footballer, born 1976)">
#   Ricardo
#  </a>
#  . Several pundits labelled Greece's tournament win the greatest upset in the history of the European Championship, with their pre-tournament
#  <a href="/wiki/Fixed-odds_betting" title="Fixed-odds betting">
#   bookmakers' odds
#  </a>
#  at
#  <span class="nowrap">
#   150–1
#  </span>
#  .
#  <a href="/wiki/2006_FIFA_World_Cup_qualification_%E2%80%93_UEFA_Group_2" title="2006 FIFA World Cup qualification – UEFA Group 2">
#   Greece subsequently failed to qualify
#  </a>
#  for the
#  <a href="/wiki/2006_FIFA_World_Cup" title="2006 FIFA World Cup">
#   2006 FIFA World Cup
#  </a>
#  and did not successfully defend their
#  <a href="/wiki/UEFA_Euro_2008" title="UEFA Euro 2008">
#   European Championship in 2008
#  </a>
#  . Portugal eventually won the
#  <a href="/wiki/UEFA_Euro_2016_final" title="UEFA Euro 2016 final">
#   European Championship in 2016
#  </a>
#  . (
#  <b>
#   <a href="/wiki/UEFA_Euro_2004_final" title="UEFA Euro 2004 final">
#    Full article...
#   </a>
#  </b>
#  )
# </p>
#
# The page is missing something! Continuing
# --------------------
# /wiki/Main_Page
# Main Page
# <p>
#  The
#  <b>
#   <a href="/wiki/UEFA_Euro_2004_final" title="UEFA Euro 2004 final">
#    UEFA Euro 2004 final
#   </a>
#  </b>
#  was the final match of
#  <a href="/wiki/UEFA_Euro_2004" title="UEFA Euro 2004">
#   Euro 2004
#  </a>
#  , the 12th
#  <a href="/wiki/UEFA_European_Championship" title="UEFA European Championship">
#   European Championship
#  </a>
#  , organised by
#  <a href="/wiki/UEFA" title="UEFA">
#   UEFA
#  </a>
#  for the senior men's national
#  <a href="/wiki/Association_football" title="Association football">
#   association football
#  </a>
#  teams of its member associations. The match was played at the
#  <a href="/wiki/Est%C3%A1dio_da_Luz" title="Estádio da Luz">
#   Estádio da Luz
#  </a>
#  in
#  <a href="/wiki/Lisbon" title="Lisbon">
#   Lisbon
#  </a>
#  , Portugal, and contested by
#  <a href="/wiki/Portugal_national_football_team" title="Portugal national football team">
#   Portugal
#  </a>
#  and
#  <a href="/wiki/Greece_national_football_team" title="Greece national football team">
#   Greece
#  </a>
#  . The two defences ensured that goal-scoring opportunities were limited, and the score was
#  <span class="nowrap">
#   0–0
#  </span>
#  at half-time. Greece scored the only goal of the match after 57 minutes when
#  <a href="/wiki/Angelos_Basinas" title="Angelos Basinas">
#   Angelos Basinas
#  </a>
#  took a
#  <a href="/wiki/Corner_kick" title="Corner kick">
#   corner kick
#  </a>
#  to
#  <a href="/wiki/Angelos_Charisteas" title="Angelos Charisteas">
#   Angelos Charisteas
#  </a>
#  , who sent a
#  <a href="/wiki/Header_(association_football)" title="Header (association football)">
#   header
#  </a>
#  past goalkeeper
#  <a href="/wiki/Ricardo_(footballer,_born_1976)" title="Ricardo (footballer, born 1976)">
#   Ricardo
#  </a>
#  . Several pundits labelled Greece's tournament win the greatest upset in the history of the European Championship, with their pre-tournament
#  <a href="/wiki/Fixed-odds_betting" title="Fixed-odds betting">
#   bookmakers' odds
#  </a>
#  at
#  <span class="nowrap">
#   150–1
#  </span>
#  .
#  <a href="/wiki/2006_FIFA_World_Cup_qualification_%E2%80%93_UEFA_Group_2" title="2006 FIFA World Cup qualification – UEFA Group 2">
#   Greece subsequently failed to qualify
#  </a>
#  for the
#  <a href="/wiki/2006_FIFA_World_Cup" title="2006 FIFA World Cup">
#   2006 FIFA World Cup
#  </a>
#  and did not successfully defend their
#  <a href="/wiki/UEFA_Euro_2008" title="UEFA Euro 2008">
#   European Championship in 2008
#  </a>
#  . Portugal eventually won the
#  <a href="/wiki/UEFA_Euro_2016_final" title="UEFA Euro 2016 final">
#   European Championship in 2016
#  </a>
#  . (
#  <b>
#   <a href="/wiki/UEFA_Euro_2004_final" title="UEFA Euro 2004 final">
#    Full article...
#   </a>
#  </b>
#  )
# </p>
#
# The page is missing something! Continuing
# --------------------
# /wiki/Wikipedia:Contents
# Wikipedia:Contents
# <p class="mw-empty-elt">
# </p>
#
# The page is missing something! Continuing
# --------------------
# /wiki/Portal:Current_events
# Portal:Current events
# <p>
#  <span class="noprint" id="coordinates">
#   <a href="/wiki/Portal:Current_events/Edit_instructions" title="Portal:Current events/Edit instructions">
#    Edit instructions
#   </a>
#  </span>
# </p>
#
# The page is missing something! Continuing
# --------------------
# /wiki/Special:Random
# List of University of Adelaide people
# <p class="mw-empty-elt">
# </p>
#
# The page is missing something! Continuing
# --------------------
# /wiki/Wikipedia:About
# Wikipedia:About
# <p class="mw-empty-elt">
# </p>
#
# The page is missing something! Continuing
# --------------------
# /wiki/Help:Contents
# Help:Contents
# <p>
#  <style data-mw-deduplicate="TemplateStyles:r1012508797">
#   .mw-parser-output .helpContents-wrapper{display:flex;flex-wrap:wrap}.mw-parser-output .helpContents-header{flex:1 0 100%;padding-bottom:1em;border-bottom:1px solid #a2a9b1;text-align:center}.mw-parser-output .helpContents-section{position:relative;flex:1 0 50%;min-width:380px;box-sizing:border-box;margin:1em 0;padding-left:30px;padding-right:20px}.mw-parser-output .helpContents-section h2{font-size:21px;padding:0;margin-top:1em;margin-bottom:0.25em;line-height:1.5}.mw-parser-output .helpContents-section ul{margin-left:0;padding-left:0}.mw-parser-output .helpContents-icon{position:absolute;top:25px;left:0;line-height:1;opacity:0.7}.mw-parser-output .helpContents-additional-search{text-align:center;margin-bottom:1em}
#  </style>
# </p>
#
# The page is missing something! Continuing
# --------------------
# /wiki/Help:Introduction
# Help:Introduction
# <p>
#  <style data-mw-deduplicate="TemplateStyles:r1231232081">
#   .mw-parser-output .introtosingle__main{position:relative;box-sizing:border-box;max-width:100%;overflow:hidden;border:1px solid var(--border-color-base,#a2a9b1);margin:auto;padding-bottom:20px}.mw-parser-output .introtosingle__main p{margin-bottom:2.0em}.mw-parser-output .introtosingle__main-withbackground{background-image:url("https://upload.wikimedia.org/wikipedia/commons/d/d9/Wikipedia-logo-v2-o10.svg");background-position:center -500px;background-repeat:no-repeat;background-size:auto 150%}.mw-parser-output .introtosingle__main-title{font-size:250%;line-height:150%;background:#777;color:#FFF;text-align:center;font-weight:bold}.mw-parser-output .introtosingle__lead{background-color:#EEE;background-color:rgba(221,221,221,0.5);padding:30px 60px;margin-bottom:15px}.mw-parser-output .introtosingle__base{box-sizing:border-box;max-width:1100px;min-height:55px;margin:auto;padding:5px 20px;font-size:1.1em;background:var(--background-color-interactive,#eaecf0);border:1px solid var(--border-color-subtle,#c8ccd1);border-top:0}.mw-parser-output .introtosingle__columns{display:flex;flex-direction:row;flex-wrap:wrap-reverse;justify-content:center}.mw-parser-output .introtosingle__columns-left,.mw-parser-output .introtosingle__columns-left-noborder,.mw-parser-output .introtosingle__columns-right{display:inline-block;flex:1 1 0;align-self:flex-end;vertical-align:top;min-width:200px;max-width:300px;padding:10px}.mw-parser-output .introtosingle__columns-left{text-align:right;justify-content:right;border-right:solid 1px #ddd}.mw-parser-output .introtosingle__columns-left-noborder{text-align:right;justify-content:right}.mw-parser-output .introtosingle__columns-right{text-align:left;justify-content:left}@media screen and (min-width:1101px){.mw-parser-output .introtosingle__main{max-width:1100px}}html.skin-theme-clientpref-night .mw-parser-output .introtosingle__lead{background-color:rgba(20,20,20,0.5)}html.skin-theme-clientpref-night .mw-parser-output .introtosingle__main-title{background-color:#24282c}@media(prefers-color-scheme:dark){html.skin-theme-clientpref-os .mw-parser-output .introtosingle__main-title{background-color:#24282c}html.skin-theme-clientpref-os .mw-parser-output .introtosingle__lead{background-color:rgba(20,20,20,0.5)}}
#  </style>
# </p>
#
# The page is missing something! Continuing
# --------------------
# /wiki/Wikipedia:Community_portal
# Wikipedia:Community portal
# <p class="mw-empty-elt">
# </p>
#
# The page is missing something! Continuing
# --------------------
# /wiki/Special:RecentChanges
# Recent changes
# <p>
#  This is a list of recent changes to Wikipedia.
# </p>
#
# The page is missing something! Continuing
# --------------------
# /wiki/Wikipedia:File_upload_wizard
# Wikipedia:File upload wizard
# <p>
#  Thank you for offering to contribute an image or other media file for use on Wikipedia. This wizard will guide you through a questionnaire prompting you for the appropriate copyright and sourcing information for each file. Please ensure you understand
#  <a href="/wiki/Wikipedia:Copyrights" title="Wikipedia:Copyrights">
#   copyright
#  </a>
#  and the
#  <a href="/wiki/Wikipedia:Image_use_policy" title="Wikipedia:Image use policy">
#   image use policy
#  </a>
#  before proceeding.
# </p>
#
# The page is missing something! Continuing
# --------------------
# /wiki/Special:Search
# Search
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 21
#      19                 pages.add(newPage)
#      20                 getLinks(newPage)
# ---> 21 getLinks('')
#
# Cell In[17], line 20, in getLinks(pageUrl)
#      18 print(newPage)
#      19 pages.add(newPage)
# ---> 20 getLinks(newPage)
#
# Cell In[17], line 20, in getLinks(pageUrl)
#      18 print(newPage)
#      19 pages.add(newPage)
# ---> 20 getLinks(newPage)
#
#     [... skipping similar frames: getLinks at line 20 (8 times)]
#
# Cell In[17], line 20, in getLinks(pageUrl)
#      18 print(newPage)
#      19 pages.add(newPage)
# ---> 20 getLinks(newPage)
#
# Cell In[17], line 7, in getLinks(pageUrl)
#       5 try:
#       6     print(bs.h1.get_text()) # Access to title
# ----> 7     print(bs.find(id ='mw-content-text').find_all('p')[0].prettify()) # Access to the first paragraph
#       8     print(bs.find(id='ca-edit').find('span')
#       9          .find('a').attrs['href'].prettify())# Get Edit links
#      10 except AttributeError:
#
# IndexError: list index out of range

# %% [markdown]
# Crawling across the internet

# %%
def getInternalLinks(bs, url):
    netloc = urlparse(url).netloc #domain www.domain.com    
    scheme = urlparse(url).scheme #protocol http or https
    internalLinks = set()
    for link in bs.find_all('a'):
        if not link.attrs.get('href'): # If the link doesnt has href then jump to next bucle iteration
            continue
        parsed = urlparse(link.attrs['href']) # we get netloc and scheme
        if parsed.netloc == '': # if the netloc is empty, then is a relative link, that means a www.samedomain.com/page
            internalLinks.add(f'{scheme}://{netloc}/{link.attrs["href"].strip("/")}') # convert this relative link in absolute link (strip delete rhe "/" in the end of link)
        elif parsed.netloc == netloc: # If the netloc is the same, then is an absolute link
            internalLinks.add(link.attrs['href']) # We just add the link 
    return list(internalLinks)

# %%
def getExternalLinks(bs, url):
    netloc = urlparse(url).netloc
    externalLinks = set()
    for link in bs.find_all('a'):
        if not link.attrs.get('href'):
            continue
        parsed = urlparse(link.attrs['href'])
        if parsed.netloc != '' and parsed.netloc != netloc: # if isn't empty and in the same page
            externalLinks.add(link.attrs['href'])
    return list(externalLinks)

# %%
def getRandomExternalLink(startingPage):
    bs = BeautifulSoup(urlopen(startingPage), 'html.parser')
    externalLinks = getExternalLinks(bs, startingPage)
    if not len(externalLinks): # if is empty
        print("No external links, looking around the site for one")
        internalLinks = getInternalLinks(bs, startingPage) # we looking for other link inside the page 
        return getRandomExternalLink(random.choice(internalLinks)) # repeat the process until get an external link
    else:
        return random.choice(externalLinks) # Return a random external link (only one)

# %%
def followExternalOnly(startingPage):
    externalLink = getRandomExternalLink(startingPage)
    print(f'Random external link is: {externalLink}')
    followExternalOnly(externalLink)

# %%
followExternalOnly('https://www.oreilly.com/')
# Out:
# Random external link is: https://learning.oreilly.com/search/?query=author%3A%22Sari%20Greene%22&extended_publisher_data=true&highlight=true&include_assessments=false&include_case_studies=true&include_courses=true&include_playlists=true&include_collections=true&include_notebooks=true&include_sandboxes=true&include_scenarios=true&is_academic_institution_account=false&source=user&sort=date_added&facet_json=true&json_facets=true&page=0&include_facets=false
# Random external link is: https://oreillylearning.in/
# Random external link is: https://www.oreilly.com/emails/newsletters/
# Random external link is: https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is: https://store.google.com/?playredirect=true
# Random external link is: https://home.nest.com/es/MX
# Random external link is: https://nest.com/-apps/learn-more-about-nest/
# No external links, looking around the site for one
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 followExternalOnly('https://www.oreilly.com/')
#
# Cell In[34], line 4, in followExternalOnly(startingPage)
#       2 externalLink = getRandomExternalLink(startingPage)
#       3 print(f'Random external link is: {externalLink}')
# ----> 4 followExternalOnly(externalLink)
#
# Cell In[34], line 4, in followExternalOnly(startingPage)
#       2 externalLink = getRandomExternalLink(startingPage)
#       3 print(f'Random external link is: {externalLink}')
# ----> 4 followExternalOnly(externalLink)
#
#     [... skipping similar frames: followExternalOnly at line 4 (4 times)]
#
# Cell In[34], line 4, in followExternalOnly(startingPage)
#       2 externalLink = getRandomExternalLink(startingPage)
#       3 print(f'Random external link is: {externalLink}')
# ----> 4 followExternalOnly(externalLink)
#
# Cell In[34], line 2, in followExternalOnly(startingPage)
#       1 def followExternalOnly(startingPage):
# ----> 2     externalLink = getRandomExternalLink(startingPage)
#       3     print(f'Random external link is: {externalLink}')
#       4     followExternalOnly(externalLink)
#
# Cell In[22], line 7, in getRandomExternalLink(startingPage)
#       5     print("No external links, looking around the site for one")
#       6     internalLinks = getInternalLinks(bs, startingPage) # we looking for other link inside the page
# ----> 7     return getRandomExternalLink(random.choice(internalLinks)) # repeat the process until get an external link
#       8 else:
#       9     return random.choice(externalLinks)
#
# File c:\Users\Carlos Ramirez\AppData\Local\Programs\Python\Python311\Lib\random.py:373, in Random.choice(self, seq)
#     370 # As an accommodation for NumPy, we don't use "if not seq"
#     371 # because bool(numpy.array()) raises a ValueError.
#     372 if not len(seq):
# --> 373     raise IndexError('Cannot choose from an empty sequence')
#     374 return seq[self._randbelow(len(seq))]
#
# IndexError: Cannot choose from an empty sequence

# %%
allExtLinks = []
allIntLinks = []

def getAllExternalLinks(url):
    bs = BeautifulSoup(urlopen(url), 'html.parser')
    internalLinks = getInternalLinks(bs, url)
    externalLinks = getExternalLinks(bs, url)
    
    for link in externalLinks:
        if link not in allExtLinks:
            allExtLinks.append(link)
            print(link)
    
    for link in internalLinks:
        if link not in allIntLinks:
            allIntLinks.append(link)
            getAllExternalLinks(link)
    

allIntLinks.append('https://oreilly.com')
getAllExternalLinks('https://www.oreilly.com/')
# Out:
# https://learning.oreilly.com/search/?query=author%3A%22Ken%20Kousen%22&extended_publisher_data=true&highlight=true&include_assessments=false&include_case_studies=true&include_courses=true&include_playlists=true&include_collections=true&include_notebooks=true&include_sandboxes=true&include_scenarios=true&is_academic_institution_account=false&source=user&sort=date_added&facet_json=true&json_facets=true&page=0&include_facets=false
# https://itunes.apple.com/us/app/safari-to-go/id881697395
# https://oreillylearning.in/
# https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# https://learning.oreilly.com/search/?query=author%3A%22Bruno%20Gon%C3%A7alves%22&extended_publisher_data=true&highlight=true&include_assessments=false&include_case_studies=true&include_courses=true&include_playlists=true&include_collections=true&include_notebooks=true&include_sandboxes=true&include_scenarios=true&is_academic_institution_account=false&source=user&sort=date_added&facet_json=true&json_facets=true&page=0&include_facets=false
# https://oreilly.hk/
# https://learning.oreilly.com/search/?query=author%3A%22Kelsey%20Hightower%22&extended_publisher_data=true&highlight=true&include_assessments=false&include_case_studies=true&include_courses=true&include_playlists=true&include_collections=true&include_notebooks=true&include_sandboxes=true&include_scenarios=true&is_academic_institution_account=false&source=user&sort=date_added&facet_json=true&json_facets=true&page=0&include_facets=false
# https://learning.oreilly.com/start-trial/
# https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# https://www.youtube.com/user/OreillyMedia
# https://www.linkedin.com/company/oreilly-media
# https://oreilly.id/
# https://www.oreilly.co.jp/index.shtml
# https://learning.oreilly.com/search/?query=author%3A%22Sari%20Greene%22&extended_publisher_data=true&highlight=true&include_assessments=false&include_case_studies=true&include_courses=true&include_playlists=true&include_collections=true&include_notebooks=true&include_sandboxes=true&include_scenarios=true&is_academic_institution_account=false&source=user&sort=date_added&facet_json=true&json_facets=true&page=0&include_facets=false
# https://learning.oreilly.com/search/?query=author%3A%22Neal%20Ford%22&extended_publisher_data=true&highlight=true&include_assessments=false&include_case_studies=true&include_courses=true&include_playlists=true&include_collections=true&include_notebooks=true&include_sandboxes=true&include_scenarios=true&is_academic_institution_account=false&source=user&sort=date_added&facet_json=true&json_facets=true&page=0&include_facets=false
# https://learning.oreilly.com/search/?query=author%3A%22Arianne%20Dee%22&extended_publisher_data=true&highlight=true&include_assessments=false&include_case_studies=true&include_courses=true&include_playlists=true&include_collections=true&include_notebooks=true&include_sandboxes=true&include_scenarios=true&is_academic_institution_account=false&source=suggestion&sort=date_added&facet_json=true&json_facets=true&page=0&include_facets=false
# https://play.google.com/store/apps/details?id=com.safariflow.queue
# https://apps.apple.com/us/app/safari-to-go/id881697395
# https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_1?dchild=1&keywords=o%27reilly&qid=1634854282&qsid=135-3308424-8155512&s=mobile-apps&sr=1-1&sres=B087YYHL5C%2CB074GDJ8QW%2CB086B7LH3N&srpt=ABIS_BOOK
# https://apps.apple.com/us/app/oreilly/id881697395
# https://play.google.com/store/apps/details?id=com.safariflow.queue&hl=en_US&gl=US
# https://chrome.google.com/webstore/detail/oreilly/honddgdnobfcbldlmimekbmphjnehbbb?hl=en-US
# https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/
# https://cdn.oreillystatic.com/pdf/OReilly_Capabilities_Statement.pdf
# https://www.applytosupply.digitalmarketplace.service.gov.uk/g-cloud/services/460643971613582
# https://www.gsaelibrary.gsa.gov/ElibMain/contractorInfo.do?contractNumber=47QTCA19D0022&contractorName=O%27REILLY+MEDIA%2C+INC&executeQuery=YES
# https://ae.oreilly.com/Modern_Defense_in_Depth
# https://www2.deloitte.com/us/en/insights/industry/technology/technology-media-and-telecom-predictions/2022/statistics-show-women-in-technology-are-facing-new-headwinds.html
# https://twitter.com/oreillymedia
# https://oreilly.com/online-learning/try-now.html
# http://oatv.com/
# https://www.civisanalytics.com/
# http://codeforamerica.org/
# https://peerj.com/
# https://www.popvox.com/
# http://conferences.oreilly.com/nextcon/economy-us?intcmp=il-business-confreg-update-ec16_new_site_tech_and_business_as_if_people_matter_body_cta
# https://www.flickr.com/photos/oreillyconf/22568721108/in/album-72157661144873811/
# http://www.mckinsey.com/global-themes/long-term-capitalism/redefining-capitalism
# https://twitter.com/oreillynext
# https://ourworldindata.org/world-poverty/#declining-global-poverty-share-of-people-living-in-extreme-poverty-1820-2015-max-roserref
# https://medium.com/the-wtf-economy/the-wtf-economy-a3bd5f52ef00#.eese0zkbs
# http://conferences.oreilly.com/nextcon/economy-us?intcmp=il-business-confreg-update-ec16_new_site_tech_and_business_as_if_people_matter_text_cta
# https://conferences.oreilly.com/nextcon/economy-us/public/register?intcmp=il-business-confreg-update-ec16_new_site_tech_and_business_as_if_people_matter_body_cta
# https://twitter.com/intent/tweet?text=Technology and business as if people matter
# http://oreilly.com/oreilly/privacy.html
# https://www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Fdevelopers.facebook.com%2Fdocs%2Fplugins%2F&src=sdkpreparse
# https://www.linkedin.com/today/author/0_31pzGngiLW-O-HpB1Dancm?trk=prof-sm
# https://www.linkedin.com/in/reidhoffman
# http://www.econ.yale.edu/smith/econ116a/keynes1.pdf
# https://creativecommons.org/licenses/by-sa/3.0/
# https://learning.oreilly.com/membership-agreement/
# https://www.copyright.gov/title17/92chap1.html#107
# https://learning.oreilly.com/apidocs/content/
# https://learning.oreilly.com/manage-groups/
# https://cdn.oreillystatic.com/images/oreilly/OReillyLogos.zip
# http://www.oreilly.com.cn/
# http://www.oreilly.co.jp
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[36], line 21
#      17             getAllExternalLinks(link)
#      20 allIntLinks.append('https://oreilly.com')
# ---> 21 getAllExternalLinks('https://www.oreilly.com/')
#
# Cell In[36], line 17, in getAllExternalLinks(url)
#      15 if link not in allIntLinks:
#      16     allIntLinks.append(link)
# ---> 17     getAllExternalLinks(link)
#
# Cell In[36], line 17, in getAllExternalLinks(url)
#      15 if link not in allIntLinks:
#      16     allIntLinks.append(link)
# ---> 17     getAllExternalLinks(link)
#
#     [... skipping similar frames: getAllExternalLinks at line 17 (15 times)]
#
# Cell In[36], line 17, in getAllExternalLinks(url)
#      15 if link not in allIntLinks:
#      16     allIntLinks.append(link)
# ---> 17     getAllExternalLinks(link)
#
# Cell In[36], line 5, in getAllExternalLinks(url)
#       4 def getAllExternalLinks(url):
# ----> 5     bs = BeautifulSoup(urlopen(url), 'html.parser')
#       6     internalLinks = getInternalLinks(bs, url)
#       7     externalLinks = getExternalLinks(bs, url)
#
# File c:\Users\Carlos Ramirez\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File c:\Users\Carlos Ramirez\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File c:\Users\Carlos Ramirez\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     631 # According to RFC 2616, "2xx" code indicates that the client's
#     632 # request was successfully received, understood, and accepted.
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File c:\Users\Carlos Ramirez\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:563, in OpenerDirector.error(self, proto, *args)
#     561 if http_err:
#     562     args = (dict, 'default', 'http_error_default') + orig_args
# --> 563     return self._call_chain(*args)
#
# File c:\Users\Carlos Ramirez\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File c:\Users\Carlos Ramirez\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:643, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     642 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 404: Not Found
